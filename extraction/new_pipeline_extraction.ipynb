# %%
"editor.fontFamily": "'JetBrains Mono', Menlo, Monaco, 'Courier New', monospace"

# %%
import os

# Recursively print a directory tree
def print_directory_tree(path):
    print(path)
    for root, dirs, files in os.walk(path):
        level = root.replace(path, '').count(os.sep) 
        indent = ' ' * 4 * (level)
        print('{}{}/'.format(indent, os.path.basename(root)))
        # subindent = ' ' * 4 * (level + 1)
        # for f in files:
        #     print('{}{}'.format(subindent, f))

data_directory = '/home/user/pulse/data'
print_directory_tree(data_directory)
# Out:
# /home/user/pulse/data
# data/
#     top/
#         insurance/
#             country/
#                 india/
#                     2023/
#                     state/
#                         chandigarh/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         sikkim/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         karnataka/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         jharkhand/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         chhattisgarh/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         maharashtra/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         andhra-pradesh/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         meghalaya/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         dadra-&-nagar-haveli-&-daman-&-diu/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         west-bengal/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         assam/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         uttar-pradesh/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         odisha/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         rajasthan/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         madhya-pradesh/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         tamil-nadu/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         ladakh/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         lakshadweep/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         punjab/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         andaman-&-nicobar-islands/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         kerala/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         uttarakhand/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         nagaland/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         telangana/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         delhi/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         goa/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         mizoram/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         gujarat/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         jammu-&-kashmir/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         arunachal-pradesh/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         puducherry/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         haryana/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         bihar/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         manipur/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         tripura/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         himachal-pradesh/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                     2021/
#                     2022/
#                     2020/
#         user/
#             country/
#                 india/
#                     2019/
#                     2023/
#                     state/
#                         chandigarh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         sikkim/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         karnataka/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         jharkhand/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         chhattisgarh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         maharashtra/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         andhra-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         meghalaya/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         dadra-&-nagar-haveli-&-daman-&-diu/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         west-bengal/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         assam/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         uttar-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         odisha/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         rajasthan/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         madhya-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         tamil-nadu/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         ladakh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         lakshadweep/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         punjab/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         andaman-&-nicobar-islands/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         kerala/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         uttarakhand/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         nagaland/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         telangana/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         delhi/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         goa/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         mizoram/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         gujarat/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         jammu-&-kashmir/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         arunachal-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         puducherry/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         haryana/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         bihar/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         manipur/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         tripura/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         himachal-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                     2021/
#                     2018/
#                     2022/
#                     2020/
#         transaction/
#             country/
#                 india/
#                     2019/
#                     2023/
#                     state/
#                         chandigarh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         sikkim/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         karnataka/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         jharkhand/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         chhattisgarh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         maharashtra/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         andhra-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         meghalaya/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         dadra-&-nagar-haveli-&-daman-&-diu/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         west-bengal/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         assam/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         uttar-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         odisha/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         rajasthan/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         madhya-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         tamil-nadu/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         ladakh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         lakshadweep/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         punjab/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         andaman-&-nicobar-islands/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         kerala/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         uttarakhand/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         nagaland/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         telangana/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         delhi/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         goa/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         mizoram/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         gujarat/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         jammu-&-kashmir/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         arunachal-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         puducherry/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         haryana/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         bihar/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         manipur/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         tripura/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         himachal-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                     2021/
#                     2018/
#                     2022/
#                     2020/
#     map/
#         insurance/
#             country/
#                 india/
#                     2023/
#                     state/
#                         chandigarh/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         sikkim/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         karnataka/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         jharkhand/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         chhattisgarh/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         maharashtra/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         andhra-pradesh/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         meghalaya/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         dadra-&-nagar-haveli-&-daman-&-diu/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         west-bengal/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         assam/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         uttar-pradesh/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         odisha/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         rajasthan/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         madhya-pradesh/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         tamil-nadu/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         ladakh/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         lakshadweep/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         punjab/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         andaman-&-nicobar-islands/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         kerala/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         uttarakhand/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         nagaland/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         telangana/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         delhi/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         goa/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         mizoram/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         gujarat/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         jammu-&-kashmir/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         arunachal-pradesh/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         puducherry/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         haryana/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         bihar/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         manipur/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         tripura/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                         himachal-pradesh/
#                             2023/
#                             2021/
#                             2022/
#                             2020/
#                     2021/
#                     2022/
#                     2020/
#             hover/
#                 country/
#                     india/
#                         2023/
#                         state/
#                             chandigarh/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             sikkim/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             karnataka/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             jharkhand/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             chhattisgarh/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             maharashtra/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             andhra-pradesh/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             meghalaya/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             dadra-&-nagar-haveli-&-daman-&-diu/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             west-bengal/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             assam/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             uttar-pradesh/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             odisha/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             rajasthan/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             madhya-pradesh/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             tamil-nadu/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             ladakh/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             lakshadweep/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             punjab/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             andaman-&-nicobar-islands/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             kerala/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             uttarakhand/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             nagaland/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             telangana/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             delhi/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             goa/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             mizoram/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             gujarat/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             jammu-&-kashmir/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             arunachal-pradesh/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             puducherry/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             haryana/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             bihar/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             manipur/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             tripura/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                             himachal-pradesh/
#                                 2023/
#                                 2021/
#                                 2022/
#                                 2020/
#                         2021/
#                         2022/
#                         2020/
#         user/
#             hover/
#                 country/
#                     india/
#                         2019/
#                         2023/
#                         state/
#                             chandigarh/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             sikkim/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             karnataka/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             jharkhand/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             chhattisgarh/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             maharashtra/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             andhra-pradesh/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             meghalaya/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             dadra-&-nagar-haveli-&-daman-&-diu/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             west-bengal/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             assam/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             uttar-pradesh/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             odisha/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             rajasthan/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             madhya-pradesh/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             tamil-nadu/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             ladakh/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             lakshadweep/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             punjab/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             andaman-&-nicobar-islands/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             kerala/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             uttarakhand/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             nagaland/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             telangana/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             delhi/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             goa/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             mizoram/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             gujarat/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             jammu-&-kashmir/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             arunachal-pradesh/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             puducherry/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             haryana/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             bihar/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             manipur/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             tripura/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                             himachal-pradesh/
#                                 2019/
#                                 2023/
#                                 2021/
#                                 2018/
#                                 2022/
#                                 2020/
#                         2021/
#                         2018/
#                         2022/
#                         2020/
#         transaction/
#             hover/
#                 country/
#                     india/
#                         2019/
#                         2023/
#                         state/
#                             chandigarh/
#                                 2019/
# ...
#                         meghalaya/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         dadra-&-nagar-haveli-&-daman-&-diu/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         west-bengal/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         assam/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         uttar-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         odisha/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         rajasthan/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         madhya-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         tamil-nadu/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         ladakh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         lakshadweep/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         punjab/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         andaman-&-nicobar-islands/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         kerala/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         uttarakhand/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         nagaland/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         telangana/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         delhi/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         goa/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         mizoram/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         gujarat/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         jammu-&-kashmir/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         arunachal-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         puducherry/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         haryana/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         bihar/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         manipur/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         tripura/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         himachal-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                     2021/
#                     2018/
#                     2022/
#                     2020/
#         transaction/
#             country/
#                 india/
#                     2019/
#                     2023/
#                     state/
#                         chandigarh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         sikkim/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         karnataka/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         jharkhand/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         chhattisgarh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         maharashtra/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         andhra-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         meghalaya/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         dadra-&-nagar-haveli-&-daman-&-diu/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         west-bengal/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         assam/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         uttar-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         odisha/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         rajasthan/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         madhya-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         tamil-nadu/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         ladakh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         lakshadweep/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         punjab/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         andaman-&-nicobar-islands/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         kerala/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         uttarakhand/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         nagaland/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         telangana/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         delhi/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         goa/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         mizoram/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         gujarat/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         jammu-&-kashmir/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         arunachal-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         puducherry/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         haryana/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         bihar/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         manipur/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         tripura/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                         himachal-pradesh/
#                             2019/
#                             2023/
#                             2021/
#                             2018/
#                             2022/
#                             2020/
#                     2021/
#                     2018/
#                     2022/
#                     2020/

# %%
import os

# Define the data directory
data_directory = '/home/user/pulse/data'

# Walk through the directory structure
for current_dir, subdirs, files in os.walk(data_directory):
    # Check if the current directory is one of the specified subfolders
    if any(subfolder in current_dir for subfolder in ['aggregated', 'map', 'top']):
        # Get the parent directory of the current directory
        parent_dir = os.path.dirname(current_dir)
        # Get the grandparent directory of the current directory
        grandparent_dir = os.path.dirname(parent_dir)
        # Print the grandparent directory and the parent directory
        print(f"Grandparent Directory: {grandparent_dir}")
        print(f"Parent Directory: {parent_dir}")
        # Print each subdirectory within the current directory
        for subdir in subdirs:
            print(f"Subdirectory: {subdir}")
# Out:
# Grandparent Directory: /home/user/pulse
# Parent Directory: /home/user/pulse/data
# Subdirectory: insurance
# Subdirectory: user
# Subdirectory: transaction
# Grandparent Directory: /home/user/pulse/data
# Parent Directory: /home/user/pulse/data/top
# Subdirectory: country
# Grandparent Directory: /home/user/pulse/data/top
# Parent Directory: /home/user/pulse/data/top/insurance
# Subdirectory: india
# Grandparent Directory: /home/user/pulse/data/top/insurance
# Parent Directory: /home/user/pulse/data/top/insurance/country
# Subdirectory: 2023
# Subdirectory: state
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country
# Parent Directory: /home/user/pulse/data/top/insurance/country/india
# Grandparent Directory: /home/user/pulse/data/top/insurance/country
# Parent Directory: /home/user/pulse/data/top/insurance/country/india
# Subdirectory: chandigarh
# Subdirectory: sikkim
# Subdirectory: karnataka
# Subdirectory: jharkhand
# Subdirectory: chhattisgarh
# Subdirectory: maharashtra
# Subdirectory: andhra-pradesh
# Subdirectory: meghalaya
# Subdirectory: dadra-&-nagar-haveli-&-daman-&-diu
# Subdirectory: west-bengal
# Subdirectory: assam
# Subdirectory: uttar-pradesh
# Subdirectory: odisha
# Subdirectory: rajasthan
# Subdirectory: madhya-pradesh
# Subdirectory: tamil-nadu
# Subdirectory: ladakh
# Subdirectory: lakshadweep
# Subdirectory: punjab
# Subdirectory: andaman-&-nicobar-islands
# Subdirectory: kerala
# Subdirectory: uttarakhand
# Subdirectory: nagaland
# Subdirectory: telangana
# Subdirectory: delhi
# Subdirectory: goa
# Subdirectory: mizoram
# Subdirectory: gujarat
# Subdirectory: jammu-&-kashmir
# Subdirectory: arunachal-pradesh
# Subdirectory: puducherry
# Subdirectory: haryana
# Subdirectory: bihar
# Subdirectory: manipur
# Subdirectory: tripura
# Subdirectory: himachal-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/chandigarh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/chandigarh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/chandigarh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/chandigarh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/sikkim
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/sikkim
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/sikkim
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/sikkim
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/karnataka
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/karnataka
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/karnataka
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/karnataka
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/jharkhand
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/jharkhand
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/jharkhand
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/jharkhand
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/maharashtra
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/maharashtra
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/maharashtra
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/maharashtra
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/meghalaya
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/meghalaya
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/meghalaya
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/meghalaya
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/west-bengal
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/west-bengal
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/west-bengal
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/west-bengal
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/assam
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/assam
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/assam
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/assam
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/odisha
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/odisha
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/odisha
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/odisha
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/rajasthan
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/rajasthan
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/rajasthan
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/rajasthan
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/ladakh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/ladakh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/ladakh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/ladakh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/lakshadweep
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/lakshadweep
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/lakshadweep
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/lakshadweep
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/punjab
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/punjab
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/punjab
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/punjab
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/andaman-&-nicobar-islands
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/andaman-&-nicobar-islands
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/andaman-&-nicobar-islands
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/andaman-&-nicobar-islands
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/kerala
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/kerala
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/kerala
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/kerala
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/uttarakhand
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/uttarakhand
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/uttarakhand
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/uttarakhand
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/nagaland
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/nagaland
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/nagaland
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/nagaland
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/telangana
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/telangana
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/telangana
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/telangana
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/delhi
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/delhi
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/delhi
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/delhi
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/goa
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/goa
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/goa
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/goa
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/mizoram
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/mizoram
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/mizoram
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/mizoram
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/gujarat
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/gujarat
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/gujarat
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/gujarat
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/jammu-&-kashmir
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/jammu-&-kashmir
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/jammu-&-kashmir
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/jammu-&-kashmir
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/arunachal-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/arunachal-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/arunachal-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/arunachal-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/puducherry
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/puducherry
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/puducherry
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/puducherry
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/haryana
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/haryana
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/haryana
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/haryana
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/bihar
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/bihar
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/bihar
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/bihar
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/manipur
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/manipur
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/manipur
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/manipur
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/tripura
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/tripura
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/tripura
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/tripura
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/himachal-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/himachal-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/himachal-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country/india/state
# Parent Directory: /home/user/pulse/data/top/insurance/country/india/state/himachal-pradesh
# Grandparent Directory: /home/user/pulse/data/top/insurance/country
# Parent Directory: /home/user/pulse/data/top/insurance/country/india
# Grandparent Directory: /home/user/pulse/data/top/insurance/country
# Parent Directory: /home/user/pulse/data/top/insurance/country/india
# Grandparent Directory: /home/user/pulse/data/top/insurance/country
# Parent Directory: /home/user/pulse/data/top/insurance/country/india
# Grandparent Directory: /home/user/pulse/data
# Parent Directory: /home/user/pulse/data/top
# Subdirectory: country
# Grandparent Directory: /home/user/pulse/data/top
# Parent Directory: /home/user/pulse/data/top/user
# Subdirectory: india
# Grandparent Directory: /home/user/pulse/data/top/user
# Parent Directory: /home/user/pulse/data/top/user/country
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: state
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/user/country
# Parent Directory: /home/user/pulse/data/top/user/country/india
# Grandparent Directory: /home/user/pulse/data/top/user/country
# Parent Directory: /home/user/pulse/data/top/user/country/india
# Grandparent Directory: /home/user/pulse/data/top/user/country
# Parent Directory: /home/user/pulse/data/top/user/country/india
# Subdirectory: chandigarh
# Subdirectory: sikkim
# Subdirectory: karnataka
# Subdirectory: jharkhand
# Subdirectory: chhattisgarh
# Subdirectory: maharashtra
# Subdirectory: andhra-pradesh
# Subdirectory: meghalaya
# Subdirectory: dadra-&-nagar-haveli-&-daman-&-diu
# Subdirectory: west-bengal
# Subdirectory: assam
# Subdirectory: uttar-pradesh
# Subdirectory: odisha
# Subdirectory: rajasthan
# Subdirectory: madhya-pradesh
# Subdirectory: tamil-nadu
# Subdirectory: ladakh
# Subdirectory: lakshadweep
# Subdirectory: punjab
# Subdirectory: andaman-&-nicobar-islands
# Subdirectory: kerala
# Subdirectory: uttarakhand
# Subdirectory: nagaland
# Subdirectory: telangana
# Subdirectory: delhi
# Subdirectory: goa
# Subdirectory: mizoram
# Subdirectory: gujarat
# Subdirectory: jammu-&-kashmir
# Subdirectory: arunachal-pradesh
# Subdirectory: puducherry
# Subdirectory: haryana
# Subdirectory: bihar
# Subdirectory: manipur
# Subdirectory: tripura
# Subdirectory: himachal-pradesh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india
# Parent Directory: /home/user/pulse/data/top/user/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/chandigarh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/chandigarh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/chandigarh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/chandigarh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/chandigarh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/chandigarh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india
# Parent Directory: /home/user/pulse/data/top/user/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/sikkim
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/sikkim
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/sikkim
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/sikkim
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/sikkim
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/sikkim
# Grandparent Directory: /home/user/pulse/data/top/user/country/india
# Parent Directory: /home/user/pulse/data/top/user/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/karnataka
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/karnataka
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/karnataka
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/karnataka
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/karnataka
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/karnataka
# Grandparent Directory: /home/user/pulse/data/top/user/country/india
# Parent Directory: /home/user/pulse/data/top/user/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/jharkhand
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/jharkhand
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/jharkhand
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/jharkhand
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/jharkhand
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/jharkhand
# Grandparent Directory: /home/user/pulse/data/top/user/country/india
# Parent Directory: /home/user/pulse/data/top/user/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/chhattisgarh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/chhattisgarh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/chhattisgarh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/chhattisgarh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/chhattisgarh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/chhattisgarh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india
# Parent Directory: /home/user/pulse/data/top/user/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/maharashtra
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/maharashtra
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/maharashtra
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/maharashtra
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/maharashtra
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/maharashtra
# Grandparent Directory: /home/user/pulse/data/top/user/country/india
# Parent Directory: /home/user/pulse/data/top/user/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/andhra-pradesh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/andhra-pradesh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/andhra-pradesh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/andhra-pradesh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/andhra-pradesh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/andhra-pradesh
# Grandparent Directory: /home/user/pulse/data/top/user/country/india
# Parent Directory: /home/user/pulse/data/top/user/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/meghalaya
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/meghalaya
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/meghalaya
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/meghalaya
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/meghalaya
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/meghalaya
# Grandparent Directory: /home/user/pulse/data/top/user/country/india
# Parent Directory: /home/user/pulse/data/top/user/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu
# Grandparent Directory: /home/user/pulse/data/top/user/country/india
# Parent Directory: /home/user/pulse/data/top/user/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/west-bengal
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/west-bengal
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/west-bengal
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/west-bengal
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/west-bengal
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/west-bengal
# Grandparent Directory: /home/user/pulse/data/top/user/country/india
# Parent Directory: /home/user/pulse/data/top/user/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/top/user/country/india/state
# Parent Directory: /home/user/pulse/data/top/user/country/india/state/assam
# ...
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/delhi
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/delhi
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/goa
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/goa
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/goa
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/goa
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/goa
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/goa
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/mizoram
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/mizoram
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/mizoram
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/mizoram
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/mizoram
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/mizoram
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/gujarat
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/gujarat
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/gujarat
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/gujarat
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/gujarat
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/gujarat
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/jammu-&-kashmir
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/jammu-&-kashmir
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/jammu-&-kashmir
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/jammu-&-kashmir
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/jammu-&-kashmir
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/jammu-&-kashmir
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/arunachal-pradesh
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/arunachal-pradesh
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/arunachal-pradesh
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/arunachal-pradesh
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/arunachal-pradesh
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/arunachal-pradesh
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/puducherry
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/puducherry
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/puducherry
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/puducherry
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/puducherry
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/puducherry
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/haryana
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/haryana
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/haryana
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/haryana
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/haryana
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/haryana
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/bihar
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/bihar
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/bihar
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/bihar
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/bihar
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/bihar
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Subdirectory: 2019
# Subdirectory: 2023
# Subdirectory: 2021
# Subdirectory: 2018
# Subdirectory: 2022
# Subdirectory: 2020
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india
# Grandparent Directory: /home/user/pulse/data/aggregated/transaction/country
# Parent Directory: /home/user/pulse/data/aggregated/transaction/country/india

# %%
import os
import json
from sqlalchemy import create_engine

def get_data_from_file(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f'File not found: {file_path}')
        return None

# Database connection
engine = create_engine('sqlite:///mydatabase.db')
data_directory = '/home/user/pulse/data'

for current_dir, subdirs, files in os.walk(data_directory):
    if 'aggregated' in current_dir or 'map' in current_dir or 'top' in current_dir:
        data_type = os.path.basename(os.path.dirname(os.path.dirname(current_dir)))
        data_type2 = os.path.basename(current_dir)

        subfolder_name = os.path.dirname(current_dir)

        # Print each subdirectory within the current directory
        # for subdir in subdirs:
        #     print(f"Subdirectory: {subdir}")

        if 'state' in current_dir:
            for state in os.listdir(current_dir):
                state_dir = os.path.join(current_dir, state)
                # Check if state_dir is a directory
                if os.path.isdir(state_dir):
                    for file in os.listdir(state_dir):
                        if file.endswith('.json'):
                            file_path = os.path.join(state_dir, file)
                            parsed_data = get_data_from_file(file_path)
                            if parsed_data is not None:
                                year = int(file_path.split('/')[-2])
                                quarter = int(file.split('.')[0])
                                state = str(file_path.split('/')[-3]).replace('-', ' ').title()
                                if 'aggregated' in current_dir:
                                    if 'insurance' in current_dir:
                                        print(data_type2)
                                        # extract_aggregated_insurance_state_data(engine, parsed_data, year, quarter, state)

# %%
for current_dir, subdirs, files in os.walk(data_directory):
    if 'aggregated' in current_dir or 'map' in current_dir or 'top' in current_dir:

# %%
import os

data_directory = '/home/user/pulse/data'

for current_dir, subdirs, files in os.walk(data_directory):
    for subdir in subdirs:
        if subdir == 'aggregated' or subdir == 'map' or subdir == 'top':
            print(f'Found subdirectory: {os.path.join(current_dir, subdir)}')

    # print(f'Found directory: {current_dir}')
    # print(f'Subdirectories: {subdirs}')
    # print(f'Files: {files}')
    # print('-------------------')
# Out:
# Found subdirectory: /home/user/pulse/data/top
# Found subdirectory: /home/user/pulse/data/map
# Found subdirectory: /home/user/pulse/data/aggregated

# %%
import os
import json
import pandas as pd
from sqlalchemy import create_engine

def get_data_from_file(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f'File not found: {file_path}')
        return None

# Database connection
engine = create_engine('sqlite:///mydatabase.db')
data_directory = '/home/user/pulse/data'
for current_dir, subdirs, files in os.walk(data_directory):
    if 'aggregated' in current_dir or 'map' in current_dir or 'top' in current_dir:
        data_type = os.path.basename(os.path.dirname(os.path.dirname(current_dir)))
        data_type2 = os.path.basename(os.path.dirname(os.path.dirname(subdirs)))
        subfolder_name = os.path.basename(current_dir)

        if 'state' in current_dir:
            for state in os.listdir(current_dir):
                state_dir = os.path.join(current_dir, state)
                # Check if state_dir is a directory
                if os.path.isdir(state_dir):
                    for file in os.listdir(state_dir):
                        if file.endswith('.json'):
                            file_path = os.path.join(state_dir, file)
                            # print(f"Processing file: {file_path}")
                            parsed_data = get_data_from_file(file_path)
                            if parsed_data is not None:
                                year = int(file_path.split('/')[-2])
                                quarter = int(file.split('.')[0])
                                state = str(file_path.split('/')[-3]).replace('-', ' ').title()
                                if 'aggregated' in current_dir:
                                    if 'insurance' in current_dir:
                                        print(data_type2)
                                        # extract_aggregated_insurance_state_data(engine, parsed_data, year, quarter, state)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/user/pulse/new_pipeline_extraction.ipynb Cell 1 line 2
#      <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> if 'aggregated' in current_dir or 'map' in current_dir or 'top' in current_dir:
#      <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a>     data_type = os.path.basename(os.path.dirname(os.path.dirname(current_dir)))
# ---> <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a>     data_type2 = os.path.basename(os.path.dirname(os.path.dirname(subdirs)))
#      <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a>     subfolder_name = os.path.basename(current_dir)
#      <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>     if 'state' in current_dir:
#
# File <frozen posixpath>:152, in dirname(p)
#
# TypeError: expected str, bytes or os.PathLike object, not list

# %%
if 'aggregated' in current_dir:
    if 'insurance' in current_dir:
        extract_aggregated_insurance_state_data(engine, parsed_data, year, quarter, state)

# %%
# Example of a data extraction function
def extract_aggregated_insurance_country_data(parsed_data, year, quarter):
    table = []
    transaction_data = parsed_data['data']['transactionData']

    for transaction in transaction_data:
        row = {
            'year': int(year),
            'quarter': int(quarter),
            'name': transaction['name'],
            'count': transaction['paymentInstruments'][0]['count'],
            'amount': transaction['paymentInstruments'][0]['amount'] 
        }
        table.append(row)

    return pd.DataFrame(table)



def extract_aggregated_transaction_country_data(parsed_data):
    table = []
    transaction_data = parsed_data['data']['transactionData']

    for transaction in transaction_data:
        row = {
            'year': int(os.path.basename(os.path.dirname(file_path))),
            'quarter': int(file.split('.')[0]),
            'name': transaction['name'],
            'count': transaction['paymentInstruments'][0]['count'],
            'amount': transaction['paymentInstruments'][0]['amount'],
        }
        table.append(row)

    return pd.DataFrame(table)



def extract_aggregated_user_country_data(parsed_data):
    table = []
    registered_users = parsed_data["data"]["aggregated"]["registeredUsers"]
    total_open_apps = parsed_data["data"]["aggregated"]["appOpens"]
    users_by_device = parsed_data["data"]["usersByDevice"]

    if users_by_device is not None:
        for user_device in users_by_device:
            row = {
                'year': int(os.path.basename(os.path.dirname(file_path))),
                'quarter': int(file.split('.')[0]),
                "registered_users": registered_users,
                "total_open_apps": total_open_apps,
                "phone_brand": user_device["brand"],
                "phone_count": user_device["count"],
                "Percentage": f"{user_device['percentage'] * 100:.2f}",
            }
            table.append(row)

    return pd.DataFrame(table)



def extract_map_insurance_hover_country_data(parsed_data):
    table = []
    hover_data_list = parsed_data["data"]["hoverDataList"]

    for entry in hover_data_list:
        metric_data = entry["metric"][0]
        row = {
            'year': int(os.path.basename(os.path.dirname(file_path))),
            'quarter': int(file.split('.')[0]),
            'state': entry["name"].replace('-', ' ').title(),
            'total_transactions_count': metric_data["count"],
            'total_transactions_amount': metric_data["amount"],
        }
        table.append(row)

    return pd.DataFrame(table)


def extract_map_insurance_hover_state_data(parsed_data):
    table = []
    hover_data_list = parsed_data["data"]["hoverDataList"]

    for entry in hover_data_list:
        district_name = entry["name"].replace('-', ' ').title()),
        metric_data = entry["metric"][0]
        total_transactions_count = metric_data["count"]
        total_transactions_amount = metric_data["amount"]

        row = {
            'year': int(os.path.basename(os.path.dirname(file_path))),
            'quarter': int(file.split('.')[0]),
            'state': state.replace('-', ' ').title(),
            'districts_name': district_name,
            'total_transactions_count': total_transactions_count,
            'total_transactions_amount': total_transactions_amount,
        }
        table.append(row)

    return pd.DataFrame(table)


def extract_map_transaction_hover_country_data(parsed_data):
    table = []
    hover_data_list = parsed_data["data"]["hoverDataList"]

    for entry in hover_data_list:
        metric_data = entry["metric"][0]
        row = {
            'year': int(os.path.basename(os.path.dirname(file_path))),
            'quarter': int(file.split('.')[0]),
            'state': entry["name"].replace('-', ' ').title(),
            'total_transactions_count': metric_data["count"],
            'total_transactions_amount': metric_data["amount"],
        }
        table.append(row)

    return pd.DataFrame(table)


def extract_map_transaction_hover_state_data(parsed_data):
    table = []
    hover_data_list = parsed_data["data"]["hoverDataList"]

    for entry in hover_data_list:
        district_name = entry["name"]
        metric_data = entry["metric"][0]
        total_transactions_count = metric_data["count"]
        total_transactions_amount = metric_data["amount"]

        row = {
            'year': int(os.path.basename(os.path.dirname(file_path))),
            'quarter': int(file.split('.')[0]),
            'state': state.replace('-', ' ').title(),
            'districts_name': district_name,
            'total_transactions_count': total_transactions_count,
            'total_transactions_amount': total_transactions_amount,
        }
        table.append(row)

    return pd.DataFrame(table)


def extract_map_user_hover_country_data(parsed_data):
    table = []
    hover_data = parsed_data["data"]["hoverData"]

    for state, state_data in hover_data.items():
        row = {
            'year': int(os.path.basename(os.path.dirname(file_path))),
            'quarter': int(file.split('.')[0]),
            'state': state.replace('-', ' ').title(),
            'registered_users': state_data["registeredUsers"],
        }
        table.append(row)

    return pd.DataFrame(table)


def extract_map_user_hover_state_data(parsed_data):
    table = []
    hover_data = parsed_data["data"]["hoverData"]

    for district, district_data in hover_data.items():
        row = {
            'year': int(os.path.basename(os.path.dirname(file_path))),
            'quarter': int(file.split('.')[0]),
            'state': state.replace('-', ' ').title(),
            'districts_name': district,
            'registered_users': district_data["registeredUsers"],
        }
        table.append(row)

    return pd.DataFrame(table)


def extract_top_insurance_country_data(parsed_data):
    entity_data = []
    for entity_type in ['states', 'districts', 'pincodes']:
        entities = parsed_data['data'][entity_type]

        for entity in entities:
            entity_row = {
                'year': int(os.path.basename(os.path.dirname(file_path))),
                'quarter': int(file.split('.')[0]),
                'entity_type': entity_type,
                'entity_name': entity['entityName'],
                'transaction_type': entity['metric']['type'],
                'count': entity['metric']['count'],
                'amount': entity['metric']['amount'],
            }
            entity_data.append(entity_row)

    return pd.DataFrame(entity_data)


def extract_top_insurance_state_data(parsed_data):
    for entity_type in ['states', 'districts', 'pincodes']:
        entities = parsed_data['data'].get(entity_type)

        if entities is not None:
            entity_data = []

            for entity in entities:
                entity_name = entity["entityName"]
                entity_metric = entity["metric"]

                row = {
                    'year': int(os.path.basename(os.path.dirname(file_path))),
                    'quarter': int(file.split('.')[0]),
                    'entity_type': entity_type,
                    'entity_name': entity_name,
                    'transaction_type': entity_metric['type'],
                    'count': entity_metric['count'],
                    'amount': entity_metric['amount'],
                }
                entity_data.append(row)

            return pd.DataFrame(entity_data)

# Function to choose appropriate data extraction function
def choose_appropriate_data_extraction_function(data_type, subfolder_name, state):
    if data_type == 'aggregated':
        if subfolder_name == 'insurance':
            if state is not None:
                return extract_aggregated_insurance_state_data
            else:
                return extract_aggregated_insurance_country_data
        elif subfolder_name == 'user':
            if state is not None:
                return extract_aggregated_user_state_data
            else:
                return extract_aggregated_user_country_data
        elif subfolder_name == 'transaction':
            if state is not None:
                return extract_aggregated_transaction_state_data
            else:
                return extract_aggregated_transaction_country_data
    elif data_type == 'map':
        if subfolder_name == 'insurance':
            if state is not None:
                return extract_map_insurance_hover_state_data
            else:
                return extract_map_insurance_hover_country_data
        elif subfolder_name == 'transaction':
            if state is not None:
                return extract_map_transaction_hover_state_data
            else:
                return extract_map_transaction_hover_country_data
        elif subfolder_name == 'user':
            if state is not None:
                return extract_map_user_hover_state_data
            else:
                return extract_map_user_hover_country_data
    elif data_type == 'top':
        if subfolder_name == 'insurance':
            if state is not None:
                return extract_top_insurance_state_data
            else:
                return extract_top_insurance_country_data

# %%
import os
import json
import pandas as pd
from sqlalchemy import create_engine

def get_data_from_file(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f'File not found: {file_path}')
        return None

# %%
def extract_aggregated_insurance_state_data(engine, parsed_data, year, quarter, state):
    table = []
    transaction_data = parsed_data['data']['transactionData']

    for transaction in transaction_data:
        row = {
            'state': state,
            'year': year,
            'quarter': quarter,
            'type_of_transaction': transaction['name'],
            'number_of_transactions': transaction['paymentInstruments'][0]['count'],
            'total_amount': transaction['paymentInstruments'][0]['amount'],
        }
        table.append(row)

    # Create a DataFrame outside of the loop
    df = pd.DataFrame(table)
    # Write to the database once, after the loop
    df.to_sql('aggregated_insurance_state', engine, index=False, if_exists='append')
    print("exytaction for aggregated_insurance_state is sucessfull")
    return df

def extract_aggregated_transaction_state_data(engine, parsed_data, year, quarter, state):
    table = []
    transaction_data = parsed_data['data']['transactionData']

    for transaction in transaction_data:
        row = {
            'state': state,
            'year': year,
            'quarter': quarter,
            'type_of_transaction': transaction['name'],
            'number_of_transactions': transaction['paymentInstruments'][0]['count'],
            'total_amount': transaction['paymentInstruments'][0]['amount'],
        }
        table.append(row)

    # Create a DataFrame outside of the loop
    df = pd.DataFrame(table)
    # Write to the database once, after the loop
    df.to_sql('aggregated_transaction_state', engine, index=False, if_exists='append')
    print("exytaction for aggregated_transaction_state is successful")
    return df

def extract_aggregated_user_state_data(engine, parsed_data, year, quarter, state):
    table = []
    registered_users = parsed_data["data"]["aggregated"]["registeredUsers"]
    total_open_apps = parsed_data["data"]["aggregated"]["appOpens"]
    users_by_device = parsed_data["data"]["usersByDevice"]

    if users_by_device is not None:
        for user_device in users_by_device:
            row = {
                'state': state,
                'year': year,
                'quarter': quarter,
                "registered_users": registered_users,
                "total_open_apps": total_open_apps,
                "phone_brand": user_device["brand"],
                "phone_count": user_device["count"],
                "Percentage": f"{user_device['percentage'] * 100:.2f}",
            }
            table.append(row)

    # Create a DataFrame outside of the loop
    df = pd.DataFrame(table)
    # Write to the database once, after the loop
    df.to_sql('aggregated_user_state', engine, index=False, if_exists='append')
    print("extraction for aggregated_user_state is successful")
    return df

# %%
def extract_map_insurance_hover_state_data(engine, parsed_data, year, quarter):
    table = []
    hover_data_list = parsed_data["data"]["hoverDataList"]

    for entry in hover_data_list:
        district_name = entry["name"].replace('-', ' ').title()
        metric_data = entry["metric"][0]
        total_transactions_count = metric_data["count"]
        total_transactions_amount = metric_data["amount"]

        row = {
            'year': year,
            'quarter': quarter,
            'state': entry["name"].replace('-', ' ').title(),
            'districts_name': district_name,
            'total_transactions_count': total_transactions_count,
            'total_transactions_amount': total_transactions_amount,
        }
        table.append(row)

    # Create a DataFrame outside of the loop
    df = pd.DataFrame(table)
    # Write to the database once, after the loop
    df.to_sql('map_insurance_hover_state', engine, index=False, if_exists='append')
    print("extraction for map_insurance_hover_state is successful")
    return df
                                    if 'map' in current_dir:

                                        if 'insurance' in current_dir:
                                            extract_map_insurance_state_data(engine, parsed_data, year, quarter, state)

                                        if 'transaction' in current_dir:

                                            extract_map_transaction_state_data(engine, parsed_data, year, quarter, state)

                                        if 'user' in current_dir:

                                            extract_map_user_state_data(engine, parsed_data, year, quarter, state)

# %%
def process_data(data_directory, engine):
    for current_dir, subdirs, files in os.walk(data_directory):
        if 'aggregated' in current_dir or 'map' in current_dir or 'top' in current_dir:
            data_type = os.path.basename(os.path.dirname(os.path.dirname(current_dir)))
            subfolder_name = os.path.basename(current_dir)

            if 'state' in current_dir:
                for state in os.listdir(current_dir):
                    state_dir = os.path.join(current_dir, state)
                    # Check if state_dir is a directory
                    if os.path.isdir(state_dir):
                        for file in os.listdir(state_dir):
                            if file.endswith('.json'):
                                file_path = os.path.join(state_dir, file)
                                # print(f"Processing file: {file_path}")
                                parsed_data = get_data_from_file(file_path)
                                if parsed_data is not None:
                                    year = int(file_path.split('/')[-2])
                                    quarter = int(file.split('.')[0])
                                    state = str(file_path.split('/')[-3]).replace('-', ' ').title()
                                    
            else:
                for file in files:
                    if file.endswith('.json'):
                        file_path = os.path.join(current_dir, file)
                        parsed_data = get_data_from_file(file_path)

                        if parsed_data is not None:
                            year = int(file_path.split('/')[-2])
                            quarter = int(file.split('.')[0])
# Database connection
engine = create_engine('sqlite:///mydatabase.db')
# Example usage
data_directory = '/home/user/pulse/data'
process_data(data_directory, engine)
# Out:
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull
# exytaction for aggregated_insurance_state is sucessfull

# %%
if 'aggregated' in current_dir:
                                        if 'insurance' in current_dir:
                                            extract_aggregated_insurance_state_data(engine, parsed_data, year, quarter, state)

# %%
if 'aggregated' in current_dir:
    if 'insurance' in current_dir:
        extract_aggregated_insurance_state_data(engine, parsed_data, year, quarter, state)

    if 'transaction' in current_dir:

        extract_aggregated_transaction_state_data(engine, parsed_data, year, quarter, state)

    if 'user' in current_dir:

        extract_aggregated_user_state_data(engine, parsed_data, year, quarter, state)

if 'map' in current_dir:

    if 'insurance' in current_dir:
        extract_map_insurance_state_data(engine, parsed_data, year, quarter, state)

    if 'transaction' in current_dir:

        extract_map_transaction_state_data(engine, parsed_data, year, quarter, state)

    if 'user' in current_dir:

        extract_map_user_state_data(engine, parsed_data, year, quarter, state)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/user/pulse/new_pipeline_extraction.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> if 'aggregated' in current_dir:
#       <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     if 'insurance' in current_dir:
#       <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>         extract_aggregated_insurance_state_data(engine, parsed_data, year, quarter, state)
#
# NameError: name 'current_dir' is not defined

# %%
import os
import json
import pandas as pd
from sqlalchemy import create_engine


def extract_aggregated_insurance_state_data(engine, parsed_data, year, quarter, state):
    table = []
    transaction_data = parsed_data['data']['transactionData']

    for transaction in transaction_data:
        row = {
            'state': state,
            'year': year,
            'quarter': quarter,
            'type_of_transaction': transaction['name'],
            'number_of_transactions': transaction['paymentInstruments'][0]['count'],
            'total_amount': transaction['paymentInstruments'][0]['amount'],
        }
        table.append(row)

    # Create a DataFrame 
    df = pd.DataFrame(table)
    # Write to the database 
    df.to_sql('aggregated_insurance_state', engine, index=False, if_exists='append')
    return df

def get_data_from_file(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f'File not found: {file_path}')
        return None


def process_data(data_directory, engine):
    quarter_data = []

    for current_dir, subdirs, files in os.walk(data_directory):
        if 'aggregated' in current_dir or 'map' in current_dir or 'top' in current_dir:
            data_type = os.path.basename(os.path.dirname(os.path.dirname(current_dir)))
            subfolder_name = os.path.basename(current_dir)

            if 'state' in current_dir:
                for state in os.listdir(current_dir):
                    state_dir = os.path.join(current_dir, state)

                    # Check if state_dir is a directory
                    if os.path.isdir(state_dir):
                        for file in os.listdir(state_dir):
                            if file.endswith('.json'):
                                file_path = os.path.join(state_dir, file)
                                parsed_data = get_data_from_file(file_path)

                                if parsed_data is not None:
                                    year = int(file_path.split('/')[-2])
                                    quarter = int(file.split('.')[0])
                                    state = state.replace('-', ' ').title()
                                    if data_type == 'aggregated':
                                        if subfolder_name == 'insurance':
                                            extract_aggregated_insurance_state_data(engine,parsed_data, year, quarter, state)



# Database connection
engine = create_engine('sqlite:///mydatabase.db')
# Example usage
data_directory = '/home/user/pulse/data'
process_data(data_directory, engine)

# %%
import os
import json
import pandas as pd
from sqlalchemy import create_engine


def extract_aggregated_insurance_state_data(engine,parsed_data,year,quarter,state):
    table = []
    transaction_data = parsed_data['data']['transactionData']

    for transaction in transaction_data:
        row = {
            'state': state,
            'year': year,
            'quarter': quarter,
            'type_of_transaction': transaction['name'],
            'number_of_transactions': transaction['paymentInstruments'][0]['count'],
            'total_amount': transaction['paymentInstruments'][0]['amount'],
        }
        table.append(row)
        df = pd.DataFrame(table)
        df.to_sql('aggregated_insurance_state', engine, index=False, if_exists='replace')
    return df

def get_data_from_file(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f'File not found: {file_path}')
        return None

def process_data(data_directory, engine):
    quarter_data = []

    for current_dir, subdirs, files in os.walk(data_directory):
        if 'aggregated' in current_dir or 'map' in current_dir or 'top' in current_dir:
            data_type = os.path.basename(os.path.dirname(os.path.dirname(current_dir)))
            subfolder_name = os.path.basename(current_dir)

            if 'state' in current_dir:
                for state in os.listdir(current_dir):
                    state_dir = os.path.join(current_dir, state)

                    for file in os.listdir(state_dir):
                        if file.endswith('.json'):
                            file_path = os.path.join(state_dir, file)
                            parsed_data = get_data_from_file(file_path)

                            if parsed_data is not None:
                                if state is not None:
                                    year = int(file_path.split('/')[-2])
                                    quarter = int(file.split('.')[0])
                                    state = state.replace('-', ' ').title()
                                    if data_type == 'aggregated':
                                        if subfolder_name == 'insurance':
                                                
                                            extract_aggregated_insurance_state_data(parsed_data,year,quarter,state)
                                    
                                    
                                            # if subfolder_name == 'transaction':

                                            #     extract_aggregated_transaction_state_data(parsed_data,year,quarter,state)

                                            # if subfolder_name == 'user':

                                            #     extract_aggregated_user_state_data(parsed_data,year,quarter,state)



            # else:
            #     for file in files:
            #         if file.endswith('.json'):
            #             file_path = os.path.join(current_dir, file)
            #             parsed_data = get_data_from_file(file_path)

            #             if parsed_data is not None:
            #                 year = int(file_path.split('/')[-2])
            #                 quarter = int(file.split('.')[0])
            #                 extract_function = choose_appropriate_data_extraction_function(data_type, subfolder_name, None)
            #                 extracted_data = extract_function(parsed_data, year, quarter)
            #                 if extracted_data is not None:
            #                     quarter_data.append(extracted_data)

# Define the data extraction functions here

# Database connection
engine = create_engine('sqlite:///mydatabase.db')
# Example usage
data_directory = '/home/user/pulse/data'
process_data(data_directory, engine)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# /home/user/pulse/new_pipeline_extraction.ipynb Cell 3 line 7
#      <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=70'>71</a> # Example usage
#      <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=71'>72</a> data_directory = '/home/user/pulse/data'
# ---> <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=72'>73</a> process_data(data_directory, engine)
#
# /home/user/pulse/new_pipeline_extraction.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a> for state in os.listdir(current_dir):
#      <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a>     state_dir = os.path.join(current_dir, state)
# ---> <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a>     for file in os.listdir(state_dir):
#      <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a>         if file.endswith('.json'):
#      <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a>             file_path = os.path.join(state_dir, file)
#
# NotADirectoryError: [Errno 20] Not a directory: '/home/user/pulse/data/top/insurance/country/india/state/chandigarh/2023/2.json'

# %%
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# /home/user/pulse/new_pipeline_extraction.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> process_data(data_directory, engine)
#
# /home/user/pulse/new_pipeline_extraction.ipynb Cell 4 line 2
#      <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a> for state in os.listdir(current_dir):
#      <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a>     state_dir = os.path.join(current_dir, state)
# ---> <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a>     for file in os.listdir(state_dir):
#      <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a>         if file.endswith('.json'):
#      <a href='vscode-notebook-cell://monospace-pulse-1707058725161.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/new_pipeline_extraction.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a>             file_path = os.path.join(state_dir, file)
#
# NotADirectoryError: [Errno 20] Not a directory: '/home/user/pulse/data/top/insurance/country/india/state/chandigarh/2023/2.json'

# %%
import os
import json
import pandas as pd
from sqlalchemy import create_engine

def get_data_from_file(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f'File not found: {file_path}')
        return None

def process_data(data_directory, engine):
    quarter_data = []

    for current_dir, subdirs, files in os.walk(data_directory):
        if 'aggregated' in current_dir:
            data_type = os.path.basename(os.path.dirname(os.path.dirname(current_dir)))
            subfolder_name = os.path.basename(current_dir)

            if 'state' in current_dir:
                for state in os.listdir(current_dir):
                    state_dir = os.path.join(current_dir, state)

                    for file in os.listdir(state_dir):
                        if file.endswith('.json'):
                            file_path = os.path.join(state_dir, file)
                            parsed_data = get_data_from_file(file_path)

                            if parsed_data is not None:
                                year = int(file_path.split('/')[-3])
                                quarter = int(file.split('.')[0])
                                extract_function = choose_appropriate_data_extraction_function(data_type, subfolder_name, state)
                                extracted_data = extract_function(parsed_data, year, quarter)
                                if extracted_data is not None:
                                    quarter_data.append(extracted_data)
            else:
                for file in files:
                    if file.endswith('.json'):
                        file_path = os.path.join(current_dir, file)
                        parsed_data = get_data_from_file(file_path)

                        if parsed_data is not None:
                            year = int(file_path.split('/')[-2])
                            quarter = int(file.split('.')[0])
                            extract_function = choose_appropriate_data_extraction_function(data_type, subfolder_name, None)
                            extracted_data = extract_function(parsed_data, year, quarter)
                            if extracted_data is not None:
                                quarter_data.append(extracted_data)

    if not quarter_data:
        print("No data to process.")
        return None

    df = pd.concat(quarter_data, ignore_index=True)
    if df.empty:
        print("No data to save to the database.")
        return None

    file_name = choose_appropriate_data_extraction_function.__name__
    try:
        df.to_sql(f'{file_name}', engine, index=False, if_exists='replace')
        engine.execute(f"CREATE INDEX idx_quarter ON {file_name} (quarter)")
    except Exception as e:
        print(f"Failed to save data to the database: {e}")
        return None

    return df

# Example of a data extraction function
def extract_aggregated_insurance_country_data(parsed_data, year, quarter):
    table = []
    transaction_data = parsed_data['data']['transactionData']

    for transaction in transaction_data:
        row = {
            'name': transaction['name'],
            'count': transaction['paymentInstruments'][0]['count'],
            'amount': transaction['paymentInstruments'][0]['amount'] 
        }
        table.append(row)

    return pd.DataFrame(table)




def extract_aggregated_insurance_state_data(parsed_data, year, quarter,state):
    table = []
    transaction_data = parsed_data['data']['transactionData']

    for transaction in transaction_data:
        row = {
            'state': state,
            'year': year,
            'quarter': quarter,
            'type_of_transaction': transaction['name'],
            'number_of_transactions': transaction['paymentInstruments'][0]['count'],
            'total_amount': transaction['paymentInstruments'][0]['amount'],
        }
        table.append(row)

    return pd.DataFrame(table)

# %%
import os
import json
import pandas as pd
from sqlalchemy import create_engine

def get_data_from_file(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f'File not found: {file_path}')
        return None

def process_data(data_directory, engine):
    quarter_data = []

    for current_dir, subdirs, files in os.walk(data_directory):
        if 'aggregated' in current_dir or 'map' in current_dir or 'top' in current_dir:
            data_type = os.path.basename(os.path.dirname(os.path.dirname(current_dir)))
            subfolder_name = os.path.basename(current_dir)

            if 'state' in current_dir:
                for state in os.listdir(current_dir):
                    state_dir = os.path.join(current_dir, state)

                    for file in os.listdir(state_dir):
                        if file.endswith('.json'):
                            file_path = os.path.join(state_dir, file)
                            parsed_data = get_data_from_file(file_path)

                            if parsed_data is not None:
                                year = int(file_path.split('/')[-3])
                                quarter = int(file.split('.')[0])
                                extract_function = choose_appropriate_data_extraction_function(data_type, subfolder_name, state)
                                extracted_data = extract_function(parsed_data, year, quarter)
                                if extracted_data is not None:
                                    quarter_data.append(extracted_data)
            else:
                for file in files:
                    if file.endswith('.json'):
                        file_path = os.path.join(current_dir, file)
                        parsed_data = get_data_from_file(file_path)

                        if parsed_data is not None:
                            year = int(file_path.split('/')[-2])
                            quarter = int(file.split('.')[0])
                            extract_function = choose_appropriate_data_extraction_function(data_type, subfolder_name, None)
                            extracted_data = extract_function(parsed_data, year, quarter)
                            if extracted_data is not None:
                                quarter_data.append(extracted_data)

    if not quarter_data:
        print("No data to process.")
        return None

    df = pd.concat(quarter_data, ignore_index=True)
    if df.empty:
        print("No data to save to the database.")
        return None

    file_name = choose_appropriate_data_extraction_function.__name__
    try:
        df.to_sql(f'{file_name}', engine, index=False, if_exists='replace')
        engine.execute(f"CREATE INDEX idx_quarter ON {file_name} (quarter)")
    except Exception as e:
        print(f"Failed to save data to the database: {e}")
        return None

    return df

# Define the data extraction functions here

# Example of a data extraction function
def extract_aggregated_insurance_country_data(parsed_data, year, quarter):
    table = []
    transaction_data = parsed_data['data']['transactionData']

    for transaction in transaction_data:
        row = {
            'year': year,
            'quarter': quarter,
            'name': transaction['name'],
            'count': transaction['paymentInstruments'][0]['count'],
            'amount': transaction['paymentInstruments'][0]['amount']  # Assuming 'amount' is a key in the JSON
        }
        table.append(row)

    return pd.DataFrame(table)

# Define the other data extraction functions here
def extract_aggregated_insurance_country_data(parsed_data):
    table = []
    transaction_data = parsed_data['data']['transactionData']

    for transaction in transaction_data:
        row = {
            'year': int(os.path.basename(os.path.dirname(file_path))),
            'quarter': int(file.split('.')[0]),
            'name': transaction['name'],
            'count': transaction['paymentInstruments'][0]['count'],
            'amount': transaction['paymentInstruments'][0]['amount'],
        }
        table.append(row)

    return pd.DataFrame(table)


def extract_aggregated_insurance_state_data(parsed_data):
    table = []
    from_timestamp = parsed_data['data']['from']
    to_timestamp = parsed_data['data']['to']
    transaction_data = parsed_data['data']['transactionData']

    for transaction in transaction_data:
        row = {
            'state': state.replace('-', ' ').title(),
            'year': int(os.path.basename(os.path.dirname(file_path))),
            'quarter': int(file.split('.')[0]),
            'from_timestamp': from_timestamp,
            'to_timestamp': to_timestamp,
            'type_of_transaction': transaction['name'],
            'number_of_transactions': transaction['paymentInstruments'][0]['count'],
            'total_amount': transaction['paymentInstruments'][0]['amount'],
        }
        table.append(row)

    return pd.DataFrame(table)


def extract_aggregated_transaction_country_data(parsed_data):
    table = []
    transaction_data = parsed_data['data']['transactionData']

    for transaction in transaction_data:
        row = {
            'year': int(os.path.basename(os.path.dirname(file_path))),
            'quarter': int(file.split('.')[0]),
            'name': transaction['name'],
            'count': transaction['paymentInstruments'][0]['count'],
            'amount': transaction['paymentInstruments'][0]['amount'],
        }
        table.append(row)

    return pd.DataFrame(table)


def extract_aggregated_transaction_state_data(parsed_data):
    table = []
    from_timestamp = parsed_data['data']['from']
    to_timestamp = parsed_data['data']['to']
    transaction_data = parsed_data['data']['transactionData']

    for transaction in transaction_data:
        row = {
            'state': state.replace('-', ' ').title(),
            'year': int(os.path.basename(os.path.dirname(file_path))),
            'quarter': int(file.split('.')[0]),
            'type_of_transaction': transaction['name'],
            'number_of_transactions': transaction['paymentInstruments'][0]['count'],
            'total_amount': transaction['paymentInstruments'][0]['amount'],
        }
        table.append(row)

    return pd.DataFrame(table)


def extract_aggregated_user_country_data(parsed_data):
    table = []
    registered_users = parsed_data["data"]["aggregated"]["registeredUsers"]
    total_open_apps = parsed_data["data"]["aggregated"]["appOpens"]
    users_by_device = parsed_data["data"]["usersByDevice"]

    if users_by_device is not None:
        for user_device in users_by_device:
            row = {
                'year': int(os.path.basename(os.path.dirname(file_path))),
                'quarter': int(file.split('.')[0]),
                "registered_users": registered_users,
                "total_open_apps": total_open_apps,
                "phone_brand": user_device["brand"],
                "phone_count": user_device["count"],
                "Percentage": f"{user_device['percentage'] * 100:.2f}",
            }
            table.append(row)

    return pd.DataFrame(table)


def extract_aggregated_user_state_data(parsed_data):
    table = []
    registered_users = parsed_data["data"]["aggregated"]["registeredUsers"]
    total_open_apps = parsed_data["data"]["aggregated"]["appOpens"]
    users_by_device = parsed_data["data"]["usersByDevice"]

    if users_by_device is not None:
        for user_device in users_by_device:
            row = {
                'state': state.replace('-', ' ').title(),
                'year': int(os.path.basename(os.path.dirname(file_path))),
                'quarter': int(file.split('.')[0]),
                "registered_users": registered_users,
                "total_open_apps": total_open_apps,
                "phone_brand": user_device["brand"],
                "phone_count": user_device["count"],
                "Percentage": f"{user_device['percentage'] * 100:.2f}",
            }
            table.append(row)

    return pd.DataFrame(table)


def extract_map_insurance_hover_country_data(parsed_data):
    table = []
    hover_data_list = parsed_data["data"]["hoverDataList"]

    for entry in hover_data_list:
        metric_data = entry["metric"][0]
        row = {
            'year': int(os.path.basename(os.path.dirname(file_path))),
            'quarter': int(file.split('.')[0]),
            'state': entry["name"].replace('-', ' ').title(),
            'total_transactions_count': metric_data["count"],
            'total_transactions_amount': metric_data["amount"],
        }
        table.append(row)

    return pd.DataFrame(table)


def extract_map_insurance_hover_state_data(parsed_data):
    table = []
    hover_data_list = parsed_data["data"]["hoverDataList"]

    for entry in hover_data_list:
        district_name = entry["name"].replace('-', ' ').title()),
        metric_data = entry["metric"][0]
        total_transactions_count = metric_data["count"]
        total_transactions_amount = metric_data["amount"]

        row = {
            'year': int(os.path.basename(os.path.dirname(file_path))),
            'quarter': int(file.split('.')[0]),
            'state': state.replace('-', ' ').title(),
            'districts_name': district_name,
            'total_transactions_count': total_transactions_count,
            'total_transactions_amount': total_transactions_amount,
        }
        table.append(row)

    return pd.DataFrame(table)


def extract_map_transaction_hover_country_data(parsed_data):
    table = []
    hover_data_list = parsed_data["data"]["hoverDataList"]

    for entry in hover_data_list:
        metric_data = entry["metric"][0]
        row = {
            'year': int(os.path.basename(os.path.dirname(file_path))),
            'quarter': int(file.split('.')[0]),
            'state': entry["name"].replace('-', ' ').title(),
            'total_transactions_count': metric_data["count"],
            'total_transactions_amount': metric_data["amount"],
        }
        table.append(row)

    return pd.DataFrame(table)


def extract_map_transaction_hover_state_data(parsed_data):
    table = []
    hover_data_list = parsed_data["data"]["hoverDataList"]

    for entry in hover_data_list:
        district_name = entry["name"]
        metric_data = entry["metric"][0]
        total_transactions_count = metric_data["count"]
        total_transactions_amount = metric_data["amount"]

        row = {
            'year': int(os.path.basename(os.path.dirname(file_path))),
            'quarter': int(file.split('.')[0]),
            'state': state.replace('-', ' ').title(),
            'districts_name': district_name,
            'total_transactions_count': total_transactions_count,
            'total_transactions_amount': total_transactions_amount,
        }
        table.append(row)

    return pd.DataFrame(table)


def extract_map_user_hover_country_data(parsed_data):
    table = []
    hover_data = parsed_data["data"]["hoverData"]

    for state, state_data in hover_data.items():
        row = {
            'year': int(os.path.basename(os.path.dirname(file_path))),
            'quarter': int(file.split('.')[0]),
            'state': state.replace('-', ' ').title(),
            'registered_users': state_data["registeredUsers"],
        }
        table.append(row)

    return pd.DataFrame(table)


def extract_map_user_hover_state_data(parsed_data):
    table = []
    hover_data = parsed_data["data"]["hoverData"]

    for district, district_data in hover_data.items():
        row = {
            'year': int(os.path.basename(os.path.dirname(file_path))),
            'quarter': int(file.split('.')[0]),
            'state': state.replace('-', ' ').title(),
            'districts_name': district,
            'registered_users': district_data["registeredUsers"],
        }
        table.append(row)

    return pd.DataFrame(table)


def extract_top_insurance_country_data(parsed_data):
    entity_data = []
    for entity_type in ['states', 'districts', 'pincodes']:
        entities = parsed_data['data'][entity_type]

        for entity in entities:
            entity_row = {
                'year': int(os.path.basename(os.path.dirname(file_path))),
                'quarter': int(file.split('.')[0]),
                'entity_type': entity_type,
                'entity_name': entity['entityName'],
                'transaction_type': entity['metric']['type'],
                'count': entity['metric']['count'],
                'amount': entity['metric']['amount'],
            }
            entity_data.append(entity_row)

    return pd.DataFrame(entity_data)


def extract_top_insurance_state_data(parsed_data):
    for entity_type in ['states', 'districts', 'pincodes']:
        entities = parsed_data['data'].get(entity_type)

        if entities is not None:
            entity_data = []

            for entity in entities:
                entity_name = entity["entityName"]
                entity_metric = entity["metric"]

                row = {
                    'year': int(os.path.basename(os.path.dirname(file_path))),
                    'quarter': int(file.split('.')[0]),
                    'entity_type': entity_type,
                    'entity_name': entity_name,
                    'transaction_type': entity_metric['type'],
                    'count': entity_metric['count'],
                    'amount': entity_metric['amount'],
                }
                entity_data.append(row)

            return pd.DataFrame(entity_data)

# Function to choose appropriate data extraction function
def choose_appropriate_data_extraction_function(data_type, subfolder_name, state):
    if data_type == 'aggregated':
        if subfolder_name == 'insurance':
            if state is not None:
                return extract_aggregated_insurance_state_data
            else:
                return extract_aggregated_insurance_country_data
        elif subfolder_name == 'user':
            if state is not None:
                return extract_aggregated_user_state_data
            else:
                return extract_aggregated_user_country_data
        elif subfolder_name == 'transaction':
            if state is not None:
                return extract_aggregated_transaction_state_data
            else:
                return extract_aggregated_transaction_country_data
    elif data_type == 'map':
        if subfolder_name == 'insurance':
            if state is not None:
                return extract_map_insurance_hover_state_data
            else:
                return extract_map_insurance_hover_country_data
        elif subfolder_name == 'transaction':
            if state is not None:
                return extract_map_transaction_hover_state_data
            else:
                return extract_map_transaction_hover_country_data
        elif subfolder_name == 'user':
            if state is not None:
                return extract_map_user_hover_state_data
            else:
                return extract_map_user_hover_country_data
    elif data_type == 'top':
        if subfolder_name == 'insurance':
            if state is not None:
                return extract_top_insurance_state_data
            else:
                return extract_top_insurance_country_data

# Database connection
engine = create_engine('sqlite:///mydatabase.db')

# Example usage
data_directory = '/home/user/pulse/data'
df = process_data(data_directory, engine)
# Out:
#   File <tokenize>:342
#     }
#     ^
# IndentationError: unindent does not match any outer indentation level
