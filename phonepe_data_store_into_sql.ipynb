# %%
import os
import json
import pandas as pd
from sqlalchemy import create_engine

def get_data_from_file(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

# Define the SQLite database file path
sqlite_file = '/home/user/myapp/test.sqlite'

# Create a SQLAlchemy engine and connect to the SQLite database
engine = create_engine(f'sqlite:///{sqlite_file}')

# %%
def process_aggregated_insurence_country(data_directory, engine):
    quarter_data = []

    for current_dir, subdirs, files in os.walk(data_directory):
        for file in files:
            file_path = os.path.join(current_dir, file)
            if os.path.isfile(file_path) and file.endswith('.json'):
                parsed_data = get_data_from_file(file_path)

                # Extract the necessary information
                transaction_data = parsed_data['data']['transactionData']

                # Check if there is any data before creating a DataFrame
                if transaction_data:
                    table = []
                    # Extract the necessary information
                    transaction_data = parsed_data['data']['transactionData']

                    # Print the extracted information without headers
                    for transaction in transaction_data:
                        row = {
                            'year': int(os.path.basename(os.path.dirname(file_path))),
                            'quarter': int(file.split('.')[0]),
                            'name': transaction['name'],
                            'count': transaction['paymentInstruments'][0]['count'],
                            'amount': transaction['paymentInstruments'][0]['amount'],
                        }
                        table.append(row)

                    df = pd.DataFrame(table)
                    quarter_data.append(df)

    # Concatenate all DataFrames
    df = pd.concat(quarter_data)

    # Save the DataFrame to the SQLite database table named 'insurance_country'
    df.to_sql('aggregated_insurence_country', engine, index=False, if_exists='replace')

    # Query the SQLite database to verify the data
    query = 'SELECT * FROM aggregated_insurence_country;'
    result_df = pd.read_sql(query, engine)
    return result_df
data_directory = '/home/user/pulse/data/aggregated/insurance/country/india'
process_aggregated_insurence_country(data_directory, engine)
# Out:
#      year  quarter       name    count        amount
# 0    2023        2  Insurance   893850  1.347400e+09
# 1    2023        1  Insurance   923173  1.408801e+09
# 2    2023        3  Insurance  1010211  1.445235e+09
# 3    2023        2  Insurance     1704  2.501107e+06
# 4    2023        1  Insurance     1520  2.415574e+06
# ..    ...      ...        ...      ...           ...
# 511  2022        3  Insurance   806491  1.054718e+09
# 512  2022        4  Insurance  1035364  1.439763e+09
# 513  2020        2  Insurance   185348  3.373217e+07
# 514  2020        3  Insurance   354284  8.949508e+07
# 515  2020        4  Insurance   248626  1.709799e+08
#
# [516 rows x 5 columns]

# %%
def process_aggregated_insurence_state(data_directory, engine):
    quarter_data = []

    for state in os.listdir(data_directory):
        state_dir = os.path.join(data_directory, state)
        
        for current_dir, subdirs, files in os.walk(state_dir):
            for file in files:
                file_path = os.path.join(current_dir, file)
                if os.path.isfile(file_path) and file.endswith('.json'):
                    parsed_data = get_data_from_file(file_path)

                    table = []
                    # Extract the necessary information
                    from_timestamp = parsed_data['data']['from']
                    to_timestamp = parsed_data['data']['to']
                    transaction_data = parsed_data['data']['transactionData']

                    # Save the extracted information 
                    for transaction in transaction_data:
                        row = {
                            'state': state.lower().replace("&", "-and").replace(" ", "-"),
                            'year': int(os.path.basename(os.path.dirname(file_path))),
                            'quarter': int(file.split('.')[0]),
                            'type_of_transaction': transaction['name'],
                            'number_of_transactions': transaction['paymentInstruments'][0]['count'],
                            'total_amount': transaction['paymentInstruments'][0]['amount'],
                        }
                        table.append(row)

                    df = pd.DataFrame(table)
                    quarter_data.append(df)

    # Concatenate all DataFrames
    df = pd.concat(quarter_data)

    # Save the DataFrame to the SQLite database table named 'aggregated_insurence_state'
    df.to_sql('aggregated_insurence_state', engine, index=False, if_exists='replace')

    # Query the SQLite database to verify the data
    query = 'SELECT * FROM aggregated_insurence_state;'
    result_df = pd.read_sql(query, engine)
    return result_df

# Example usage:
data_directory_state = '/home/user/pulse/data/aggregated/insurance/country/india/state'

result_df = process_aggregated_insurence_state(data_directory_state, engine)
result_df
# Out:
#                 state  year  quarter type_of_transaction  \
# 0          chandigarh  2023        2           Insurance
# 1          chandigarh  2023        1           Insurance
# 2          chandigarh  2023        3           Insurance
# 3          chandigarh  2021        2           Insurance
# 4          chandigarh  2021        1           Insurance
# ..                ...   ...      ...                 ...
# 497  himachal-pradesh  2022        3           Insurance
# 498  himachal-pradesh  2022        4           Insurance
# 499  himachal-pradesh  2020        2           Insurance
# 500  himachal-pradesh  2020        3           Insurance
# 501  himachal-pradesh  2020        4           Insurance
#
#      number_of_transactions  total_amount
# 0                      1704     2501107.0
# 1                      1520     2415574.0
# 2                      1883     2660630.0
# 3                       378      310943.0
# 4                       338      238576.0
# ..                      ...           ...
# 497                    3641     6161692.0
# 498                    4565     9060436.0
# 499                     392       77936.0
# 500                     531      165559.0
# 501                     710      630966.0
#
# [502 rows x 6 columns]

# %%
import os

data_directory = '/home/user/pulse/data'

for current_dir, subdirs, files in os.walk(data_directory):
    # `current_dir` is the current directory being traversed
    print("Current Directory:", current_dir)

    # `subdirs` is a list of subdirectories in the current directory
    print("Subdirectories:", subdirs)

    # `files` is a list of files in the current directory
    print("Files:", files)

    # Now, you can use `subdirs` to access the subdirectories within the current directory
    for subdir in subdirs:
        sub_dir_path = os.path.join(current_dir, subdir)
        print("Subdirectory Path:", sub_dir_path)

    # Similarly, you can use `files` to access the files within the current directory
    for file in files:
        file_path = os.path.join(current_dir, file)
        print("File Path:", file_path)

    # You can perform additional operations or logic here based on the current directory, subdirectories, and files
    # ...

    print("-" * 50)  # Just for better visualization of different iterations
# Out:
# Current Directory: /home/user/pulse/data
# Subdirectories: ['top', 'map', 'aggregated']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top
# Subdirectory Path: /home/user/pulse/data/map
# Subdirectory Path: /home/user/pulse/data/aggregated
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top
# Subdirectories: ['insurance', 'user', 'transaction']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance
# Subdirectory Path: /home/user/pulse/data/top/user
# Subdirectory Path: /home/user/pulse/data/top/transaction
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance
# Subdirectories: ['country']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country
# Subdirectories: ['india']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india
# Subdirectories: ['2023', 'state', '2021', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/2023
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/2021
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/2022
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/2023/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/2023/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state
# Subdirectories: ['chandigarh', 'sikkim', 'karnataka', 'jharkhand', 'chhattisgarh', 'maharashtra', 'andhra-pradesh', 'meghalaya', 'dadra-&-nagar-haveli-&-daman-&-diu', 'west-bengal', 'assam', 'uttar-pradesh', 'odisha', 'rajasthan', 'madhya-pradesh', 'tamil-nadu', 'ladakh', 'lakshadweep', 'punjab', 'andaman-&-nicobar-islands', 'kerala', 'uttarakhand', 'nagaland', 'telangana', 'delhi', 'goa', 'mizoram', 'gujarat', 'jammu-&-kashmir', 'arunachal-pradesh', 'puducherry', 'haryana', 'bihar', 'manipur', 'tripura', 'himachal-pradesh']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/assam
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/odisha
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/ladakh
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/lakshadweep
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/punjab
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/andaman-&-nicobar-islands
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/kerala
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/uttarakhand
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/nagaland
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/telangana
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/delhi
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/goa
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/mizoram
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/gujarat
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/jammu-&-kashmir
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/arunachal-pradesh
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/puducherry
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/haryana
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/bihar
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/manipur
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/tripura
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/himachal-pradesh
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/chandigarh
# Subdirectories: ['2023', '2021', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2023
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2021
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2022
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2023/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2023/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2021/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2021/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2021/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2022/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2022/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2022/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2020
# Subdirectories: []
# Files: ['2.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2020/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2020/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/sikkim
# Subdirectories: ['2023', '2021', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2023
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2021
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2022
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2023/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2023/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2021/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2021/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2021/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2022/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2022/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2022/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2020
# Subdirectories: []
# Files: ['2.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2020/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2020/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/sikkim/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/karnataka
# Subdirectories: ['2023', '2021', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2023
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2021
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2022
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2023/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2023/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2021/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2021/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2021/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2022/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2022/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2022/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2020
# Subdirectories: []
# Files: ['2.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2020/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2020/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/karnataka/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/jharkhand
# Subdirectories: ['2023', '2021', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2023
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2021
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2022
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2023/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2023/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2021/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2021/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2021/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2022/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2022/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2022/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2020
# Subdirectories: []
# Files: ['2.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2020/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2020/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/jharkhand/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh
# Subdirectories: ['2023', '2021', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2023
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2021
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2022
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2023/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2023/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2021/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2021/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2021/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2022/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2022/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2022/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2020
# Subdirectories: []
# Files: ['2.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2020/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2020/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/chhattisgarh/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/maharashtra
# Subdirectories: ['2023', '2021', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2023
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2021
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2022
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2023/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2023/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2021/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2021/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2021/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2022/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2022/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2022/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2020
# Subdirectories: []
# Files: ['2.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2020/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2020/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/maharashtra/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh
# Subdirectories: ['2023', '2021', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2023
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2021
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2022
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2023/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2023/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2021/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2021/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2021/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2022/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2022/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2022/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2020
# Subdirectories: []
# Files: ['2.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2020/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2020/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/andhra-pradesh/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/meghalaya
# Subdirectories: ['2023', '2021', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2023
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2021
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2022
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2023/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2023/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2021/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2021/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2021/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2022/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2022/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2022/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2020
# Subdirectories: []
# Files: ['2.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2020/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2020/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/meghalaya/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu
# Subdirectories: ['2023', '2021', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2023
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2021
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2022
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2023/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2023/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2021/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2021/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2021/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2022/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2022/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2022/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2020
# Subdirectories: []
# Files: ['2.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2020/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2020/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/west-bengal
# Subdirectories: ['2023', '2021', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2023
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2021
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2022
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2023/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2023/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2021/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2021/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2021/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2022/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2022/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2022/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2020
# Subdirectories: []
# Files: ['2.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2020/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2020/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/west-bengal/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/assam
# Subdirectories: ['2023', '2021', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2023
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2021
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2022
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/assam/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2023/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2023/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/assam/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2021/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2021/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2021/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/assam/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2022/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2022/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2022/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/assam/2020
# Subdirectories: []
# Files: ['2.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2020/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2020/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/assam/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh
# Subdirectories: ['2023', '2021', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2023
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2021
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2022
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2023/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2023/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2021/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2021/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2021/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2022/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2022/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2022/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2020
# Subdirectories: []
# Files: ['2.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2020/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2020/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/uttar-pradesh/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/odisha
# Subdirectories: ['2023', '2021', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2023
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2021
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2022
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/odisha/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2023/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2023/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/odisha/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2021/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2021/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2021/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/odisha/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2022/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2022/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2022/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/odisha/2020
# Subdirectories: []
# Files: ['2.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2020/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2020/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/odisha/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/rajasthan
# Subdirectories: ['2023', '2021', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2023
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2021
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2022
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2023/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2023/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2021/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2021/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2021/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2022/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2022/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2022/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2020
# Subdirectories: []
# Files: ['2.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2020/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2020/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/rajasthan/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh
# Subdirectories: ['2023', '2021', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2023
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2021
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2022
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2023/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2023/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2021/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2021/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2021/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2022/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2022/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2022/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2020
# Subdirectories: []
# Files: ['2.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2020/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2020/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/madhya-pradesh/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu
# Subdirectories: ['2023', '2021', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2023
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2021
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2022
# Subdirectory Path: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2023/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2023/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2021/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2021/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2021/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2022/2.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2022/1.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2022/3.json
# File Path: /home/user/pulse/data/top/insurance/country/india/state/tamil-nadu/2022/4.json
# --------------------------------------------------
# ...
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/bihar/2020
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/bihar/2020/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/bihar/2020/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/bihar/2020/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/bihar/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur
# Subdirectories: ['2019', '2023', '2021', '2018', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2019
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2023
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2021
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2018
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2022
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2019
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2019/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2019/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2019/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2019/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2023/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2023/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2021/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2021/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2021/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2018
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2018/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2018/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2018/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2018/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2022/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2022/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2022/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2020
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2020/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2020/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2020/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/manipur/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura
# Subdirectories: ['2019', '2023', '2021', '2018', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2019
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2023
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2021
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2018
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2022
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2019
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2019/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2019/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2019/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2019/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2023/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2023/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2021/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2021/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2021/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2018
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2018/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2018/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2018/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2018/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2022/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2022/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2022/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2020
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2020/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2020/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2020/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/tripura/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh
# Subdirectories: ['2019', '2023', '2021', '2018', '2022', '2020']
# Files: []
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2019
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2023
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2021
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2018
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2022
# Subdirectory Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2020
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2019
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2019/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2019/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2019/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2019/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2023
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2023/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2023/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2023/3.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2021/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2021/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2021/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2018
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2018/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2018/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2018/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2018/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2022/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2022/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2022/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2020
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2020/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2020/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2020/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/2020/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/2021
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/2021/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/2021/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/2021/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/2021/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/2018
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/2018/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/2018/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/2018/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/2018/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/2022
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/2022/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/2022/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/2022/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/2022/4.json
# --------------------------------------------------
# Current Directory: /home/user/pulse/data/aggregated/transaction/country/india/2020
# Subdirectories: []
# Files: ['2.json', '1.json', '3.json', '4.json']
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/2020/2.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/2020/1.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/2020/3.json
# File Path: /home/user/pulse/data/aggregated/transaction/country/india/2020/4.json
# --------------------------------------------------

# %%
data_directory = '/home/user/pulse/data'
for current_dir, subdirs, files in os.walk(data_directory):
    for subdir in os.walk(subdirs):
        if top in subdir:
            pass

        if map in subdir:
            pass

        if aggregated in subdir:
            
            for file in files:
                file_path = os.path.join(current_dir, file)
                if os.path.isfile(file_path) and file.endswith('.json'):
                    if 'insurance' and not 'state' in subdirs:
                        
                            parsed_data = get_data_from_file(file_path)

                            # Extract the necessary information
                            transaction_data = parsed_data['data']['transactionData']

                            # Check if there is any data before creating a DataFrame
                            if transaction_data:
                                table = []
                                # Extract the necessary information
                                transaction_data = parsed_data['data']['transactionData']

                                # Print the extracted information without headers
                                for transaction in transaction_data:
                                    row = {
                                        'year': int(os.path.basename(os.path.dirname(file_path))),
                                        'quarter': int(file.split('.')[0]),
                                        'name': transaction['name'],
                                        'count': transaction['paymentInstruments'][0]['count'],
                                        'amount': transaction['paymentInstruments'][0]['amount'],
                                    }
                                    table.append(row)

                        
                                df = pd.DataFrame(table)
                                quarter_data.append(df)
                    if 'insurance' and 'state' in subdirs:
                            parsed_data = get_data_from_file(file_path)

                            table = []
                            # Extract the necessary information
                            from_timestamp = parsed_data['data']['from']
                            to_timestamp = parsed_data['data']['to']
                            transaction_data = parsed_data['data']['transactionData']

                            # Save the extracted information 
                            for transaction in transaction_data:
                                row = {
                                    'state': state.lower().replace("&", "-and").replace(" ", "-"),
                                    'year': int(os.path.basename(os.path.dirname(file_path))),
                                    'quarter': int(file.split('.')[0]),
                                    'from_timestamp': from_timestamp,
                                    'to_timestamp': to_timestamp,
                                    'type_of_transaction': transaction['name'],
                                    'number_of_transactions': transaction['paymentInstruments'][0]['count'],
                                    'total_amount': transaction['paymentInstruments'][0]['amount'],
                                }
                                table.append(row)

                    df = pd.DataFrame(table)
                    quarter_data.append(df)

                








    # Concatenate all DataFrames
    df = pd.concat(quarter_data)

    # Save the DataFrame to the SQLite database table named 'insurance_country'
    df.to_sql(f'{aggregated}_{insurence}_{country}', engine, index=False, if_exists='replace')
# Out:
# top
# map
# aggregated
# insurance
# user
# transaction
# country
# india
# 2023
# state
# 2021
# 2022
# 2020
# chandigarh
# sikkim
# karnataka
# jharkhand
# chhattisgarh
# maharashtra
# andhra-pradesh
# meghalaya
# dadra-&-nagar-haveli-&-daman-&-diu
# west-bengal
# assam
# uttar-pradesh
# odisha
# rajasthan
# madhya-pradesh
# tamil-nadu
# ladakh
# lakshadweep
# punjab
# andaman-&-nicobar-islands
# kerala
# uttarakhand
# nagaland
# telangana
# delhi
# goa
# mizoram
# gujarat
# jammu-&-kashmir
# arunachal-pradesh
# puducherry
# haryana
# bihar
# manipur
# tripura
# himachal-pradesh
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# country
# india
# 2019
# 2023
# state
# 2021
# 2018
# 2022
# 2020
# chandigarh
# sikkim
# karnataka
# jharkhand
# chhattisgarh
# maharashtra
# andhra-pradesh
# meghalaya
# dadra-&-nagar-haveli-&-daman-&-diu
# west-bengal
# assam
# uttar-pradesh
# odisha
# rajasthan
# madhya-pradesh
# tamil-nadu
# ladakh
# lakshadweep
# punjab
# andaman-&-nicobar-islands
# kerala
# uttarakhand
# nagaland
# telangana
# delhi
# goa
# mizoram
# gujarat
# jammu-&-kashmir
# arunachal-pradesh
# puducherry
# haryana
# bihar
# manipur
# tripura
# himachal-pradesh
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# country
# india
# 2019
# 2023
# state
# 2021
# 2018
# 2022
# 2020
# chandigarh
# sikkim
# karnataka
# jharkhand
# chhattisgarh
# maharashtra
# andhra-pradesh
# meghalaya
# dadra-&-nagar-haveli-&-daman-&-diu
# west-bengal
# assam
# uttar-pradesh
# odisha
# rajasthan
# madhya-pradesh
# tamil-nadu
# ladakh
# lakshadweep
# punjab
# andaman-&-nicobar-islands
# kerala
# uttarakhand
# nagaland
# telangana
# delhi
# goa
# mizoram
# gujarat
# jammu-&-kashmir
# arunachal-pradesh
# puducherry
# haryana
# bihar
# manipur
# tripura
# himachal-pradesh
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# insurance
# user
# transaction
# country
# hover
# india
# 2023
# state
# 2021
# 2022
# 2020
# chandigarh
# sikkim
# karnataka
# jharkhand
# chhattisgarh
# maharashtra
# andhra-pradesh
# meghalaya
# dadra-&-nagar-haveli-&-daman-&-diu
# west-bengal
# assam
# uttar-pradesh
# odisha
# rajasthan
# madhya-pradesh
# tamil-nadu
# ladakh
# lakshadweep
# punjab
# andaman-&-nicobar-islands
# kerala
# uttarakhand
# nagaland
# telangana
# delhi
# goa
# mizoram
# gujarat
# jammu-&-kashmir
# arunachal-pradesh
# puducherry
# haryana
# bihar
# manipur
# tripura
# himachal-pradesh
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# country
# india
# 2023
# state
# 2021
# 2022
# 2020
# chandigarh
# sikkim
# karnataka
# jharkhand
# chhattisgarh
# maharashtra
# andhra-pradesh
# meghalaya
# dadra-&-nagar-haveli-&-daman-&-diu
# west-bengal
# assam
# uttar-pradesh
# odisha
# rajasthan
# madhya-pradesh
# tamil-nadu
# ladakh
# lakshadweep
# punjab
# andaman-&-nicobar-islands
# kerala
# uttarakhand
# nagaland
# telangana
# delhi
# goa
# mizoram
# gujarat
# jammu-&-kashmir
# arunachal-pradesh
# puducherry
# haryana
# bihar
# manipur
# tripura
# himachal-pradesh
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# hover
# country
# india
# 2019
# 2023
# state
# 2021
# 2018
# 2022
# 2020
# chandigarh
# sikkim
# karnataka
# jharkhand
# chhattisgarh
# maharashtra
# andhra-pradesh
# meghalaya
# dadra-&-nagar-haveli-&-daman-&-diu
# west-bengal
# assam
# uttar-pradesh
# odisha
# rajasthan
# madhya-pradesh
# tamil-nadu
# ladakh
# lakshadweep
# punjab
# andaman-&-nicobar-islands
# kerala
# uttarakhand
# nagaland
# telangana
# delhi
# goa
# mizoram
# gujarat
# jammu-&-kashmir
# arunachal-pradesh
# puducherry
# haryana
# bihar
# manipur
# tripura
# himachal-pradesh
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# hover
# country
# india
# 2019
# 2023
# state
# 2021
# 2018
# 2022
# 2020
# chandigarh
# sikkim
# karnataka
# jharkhand
# chhattisgarh
# maharashtra
# andhra-pradesh
# meghalaya
# dadra-&-nagar-haveli-&-daman-&-diu
# west-bengal
# assam
# uttar-pradesh
# odisha
# rajasthan
# madhya-pradesh
# tamil-nadu
# ladakh
# lakshadweep
# punjab
# andaman-&-nicobar-islands
# kerala
# uttarakhand
# nagaland
# telangana
# delhi
# goa
# mizoram
# gujarat
# jammu-&-kashmir
# arunachal-pradesh
# puducherry
# haryana
# bihar
# manipur
# tripura
# himachal-pradesh
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# insurance
# user
# transaction
# country
# india
# 2023
# state
# 2021
# 2022
# 2020
# chandigarh
# sikkim
# karnataka
# jharkhand
# chhattisgarh
# maharashtra
# andhra-pradesh
# meghalaya
# dadra-&-nagar-haveli-&-daman-&-diu
# west-bengal
# assam
# uttar-pradesh
# odisha
# rajasthan
# madhya-pradesh
# tamil-nadu
# ladakh
# lakshadweep
# punjab
# andaman-&-nicobar-islands
# kerala
# uttarakhand
# nagaland
# telangana
# delhi
# goa
# mizoram
# gujarat
# jammu-&-kashmir
# arunachal-pradesh
# puducherry
# haryana
# bihar
# manipur
# tripura
# himachal-pradesh
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# 2023
# 2021
# 2022
# 2020
# country
# india
# 2019
# 2023
# state
# 2021
# 2018
# 2022
# 2020
# chandigarh
# sikkim
# karnataka
# jharkhand
# chhattisgarh
# maharashtra
# andhra-pradesh
# meghalaya
# dadra-&-nagar-haveli-&-daman-&-diu
# west-bengal
# assam
# uttar-pradesh
# odisha
# rajasthan
# madhya-pradesh
# tamil-nadu
# ladakh
# lakshadweep
# punjab
# andaman-&-nicobar-islands
# kerala
# uttarakhand
# nagaland
# telangana
# delhi
# goa
# mizoram
# gujarat
# jammu-&-kashmir
# arunachal-pradesh
# puducherry
# haryana
# bihar
# manipur
# tripura
# himachal-pradesh
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# country
# india
# 2019
# 2023
# state
# 2021
# 2018
# 2022
# 2020
# chandigarh
# sikkim
# karnataka
# jharkhand
# chhattisgarh
# maharashtra
# andhra-pradesh
# meghalaya
# dadra-&-nagar-haveli-&-daman-&-diu
# west-bengal
# assam
# uttar-pradesh
# odisha
# rajasthan
# madhya-pradesh
# tamil-nadu
# ladakh
# lakshadweep
# punjab
# andaman-&-nicobar-islands
# kerala
# uttarakhand
# nagaland
# telangana
# delhi
# goa
# mizoram
# gujarat
# jammu-&-kashmir
# arunachal-pradesh
# puducherry
# haryana
# bihar
# manipur
# tripura
# himachal-pradesh
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020
# 2019
# 2023
# 2021
# 2018
# 2022
# 2020

# %%
import os
import pandas as pd

def process_aggregated_transaction_country(data_directory, engine):
    quarter_data = []

    for current_dir, subdirs, files in os.walk(data_directory):
        if 'state' in subdirs:
            break
        else:
            for file in files:
                file_path = os.path.join(current_dir, file)
                if os.path.isfile(file_path) and file.endswith('.json'):
                    parsed_data = get_data_from_file(file_path)

                    table = []
                    # Extract the necessary information
                    transaction_data = parsed_data['data']['transactionData']

                    # Save the extracted information without headers
                    for transaction in transaction_data:
                        row = {
                            'year': int(os.path.basename(os.path.dirname(file_path))),
                            'quarter': int(file.split('.')[0]),
                            'name': transaction['name'],
                            'count': transaction['paymentInstruments'][0]['count'],
                            'amount': transaction['paymentInstruments'][0]['amount'],
                        }
                        table.append(row)

                    df = pd.DataFrame(table)
                    quarter_data.append(df)

    # Check if there are any DataFrames to concatenate
    if quarter_data:
        # Concatenate all DataFrames
        df = pd.concat(quarter_data)

        # Save the DataFrame to the SQLite database table named 'aggregated_transaction_country'
        df.to_sql('aggregated_transaction_country', engine, index=False, if_exists='replace')
    else:
        # print("No eligible files found for concatenation.")
        pass
    # Query the SQLite database to verify the data
    query = 'SELECT * FROM aggregated_transaction_country;'
    result_df = pd.read_sql(query, engine)
    return result_df

data_aggregated_transaction_country = '/home/user/pulse/data/aggregated/transaction/country/india/'
result_df = process_aggregated_transaction_country(data_aggregated_transaction_country, engine)
result_df
# Out:
#       year  quarter                      name       count        amount
# 0     2019        2     Peer-to-peer payments   384711008  1.196425e+12
# 1     2019        2  Recharge & bill payments   209898072  7.686585e+10
# 2     2019        2         Merchant payments   206467182  7.341584e+10
# 3     2019        2        Financial Services     2650384  5.453293e+08
# 4     2019        2                    Others    11656557  6.969424e+09
# ...    ...      ...                       ...         ...           ...
# 4244  2020        4     Peer-to-peer payments  1249512647  4.474548e+12
# 4245  2020        4         Merchant payments  1127490136  6.848736e+11
# 4246  2020        4  Recharge & bill payments   479784084  2.278758e+11
# 4247  2020        4        Financial Services     2942567  3.259168e+09
# 4248  2020        4                    Others     9556404  5.323095e+09
#
# [4249 rows x 5 columns]

# %%
def process_aggregated_transaction_state(data_directory, engine):
    quarter_data = []

    for state in os.listdir(data_directory):
        state_dir = os.path.join(data_directory, state)
        
        for current_dir, subdirs, files in os.walk(state_dir):
            for file in files:
                file_path = os.path.join(current_dir, file)
                if os.path.isfile(file_path) and file.endswith('.json'):
                    parsed_data = get_data_from_file(file_path)

                    table = []
                    # Extract the necessary information
                    from_timestamp = parsed_data['data']['from']
                    to_timestamp = parsed_data['data']['to']
                    transaction_data = parsed_data['data']['transactionData']

                    # Save the data
                    for transaction in transaction_data:
                        row = {
                            'state': state.lower().replace("&", "-and").replace(" ", "-"),
                            'year': int(os.path.basename(os.path.dirname(file_path))),
                            'quarter': int(file.split('.')[0]),
                            # 'from_timestamp': from_timestamp,
                            # 'to_timestamp': to_timestamp,
                            'type_of_transaction': transaction['name'],
                            'number_of_transactions': transaction['paymentInstruments'][0]['count'],
                            'total_amount': transaction['paymentInstruments'][0]['amount'],
                        }
                        table.append(row)

                    df = pd.DataFrame(table)
                    quarter_data.append(df)

    # Concatenate all DataFrames
    df = pd.concat(quarter_data)

    # Save the DataFrame to the SQLite database table named 'aggregated_transaction_state'
    df.to_sql('aggregated_transaction_state', engine, index=False, if_exists='replace')

    # Query the SQLite database to verify the data
    query = 'SELECT * FROM aggregated_transaction_state;'
    result_df = pd.read_sql(query, engine)
    return result_df
data_aggregated_transaction_state = '/home/user/pulse/data/aggregated/transaction/country/india/state/'
result_df = process_aggregated_transaction_state(data_aggregated_transaction_state, engine)
result_df
# Out:
#                  state  year  quarter       type_of_transaction  \
# 0           chandigarh  2019        2     Peer-to-peer payments
# 1           chandigarh  2019        2  Recharge & bill payments
# 2           chandigarh  2019        2         Merchant payments
# 3           chandigarh  2019        2        Financial Services
# 4           chandigarh  2019        2                    Others
# ...                ...   ...      ...                       ...
# 4129  himachal-pradesh  2020        4  Recharge & bill payments
# 4130  himachal-pradesh  2020        4     Peer-to-peer payments
# 4131  himachal-pradesh  2020        4         Merchant payments
# 4132  himachal-pradesh  2020        4        Financial Services
# 4133  himachal-pradesh  2020        4                    Others
#
#       number_of_transactions  total_amount
# 0                     604849  2.339922e+09
# 1                     342294  1.856590e+08
# 2                     277811  1.527669e+08
# 3                       5590  8.397652e+05
# 4                      21926  1.392805e+07
# ...                      ...           ...
# 4129                 2638030  9.363058e+08
# 4130                 2594659  1.142627e+10
# 4131                 2001259  1.589433e+09
# 4132                   11353  1.553425e+07
# 4133                   27027  2.151078e+07
#
# [4134 rows x 6 columns]

# %%
def process_aggregated_user_country(data_directory, engine):
    quarter_data = []

    for current_dir, subdirs, files in os.walk(data_directory):
        for file in files:
            file_path = os.path.join(current_dir, file)
            if os.path.isfile(file_path) and file.endswith('.json'):
                parsed_data = get_data_from_file(file_path)

                table = []
                # Extract the necessary information
                registered_users = parsed_data["data"]["aggregated"]["registeredUsers"]
                total_open_apps = parsed_data["data"]["aggregated"]["appOpens"]
                users_by_device = parsed_data["data"]["usersByDevice"]

                # Check if users_by_device is not None before iterating
                if users_by_device is not None:
                    # Save the extracted information
                    for user_device in users_by_device:
                        row = {
                            'year': int(os.path.basename(os.path.dirname(file_path))),
                            'quarter': int(file.split('.')[0]),
                            "registered_users": registered_users,
                            "total_open_apps": total_open_apps,
                            "phone_brand": user_device["brand"],
                            "phone_count": user_device["count"],
                            "Percentage": f"{user_device['percentage'] * 100:.2f}",
                        }
                        table.append(row)

                df = pd.DataFrame(table)
                quarter_data.append(df)

    # Concatenate all DataFrames
    df = pd.concat(quarter_data)


    # Save the DataFrame to the SQLite database table named 'aggregated_user_country'
    df.to_sql('aggregated_user_country', engine, index=False, if_exists='replace')

    # Query the SQLite database to verify the data
    query = 'SELECT * FROM aggregated_user_country;'
    result_df = pd.read_sql(query, engine)
    return result_df


# Example usage:
data_aggregated_user_country = '/home/user/pulse/data/aggregated/user/country/india/'
result_df = process_aggregated_user_country(data_aggregated_user_country, engine)
result_df
# Out:
#       year  quarter  registered_users  total_open_apps phone_brand  \
# 0     2019        2         141808226        920413791      Xiaomi
# 1     2019        2         141808226        920413791     Samsung
# 2     2019        2         141808226        920413791        Vivo
# 3     2019        2         141808226        920413791        Oppo
# 4     2019        2         141808226        920413791      Realme
# ...    ...      ...               ...              ...         ...
# 6914  2020        4         264271293       7461623162    Motorola
# 6915  2020        4         264271293       7461623162      Huawei
# 6916  2020        4         264271293       7461623162     OnePlus
# 6917  2020        4         264271293       7461623162      Lenovo
# 6918  2020        4         264271293       7461623162      Others
#
#       phone_count Percentage
# 0        36936092      26.05
# 1        28857066      20.35
# 2        22157338      15.62
# 3        15797055      11.14
# 4         6829373       4.82
# ...           ...        ...
# 6914      5650618       2.14
# 6915      4915828       1.86
# 6916      4621214       1.75
# 6917      3880170       1.47
# 6918     22375116       8.47
#
# [6919 rows x 7 columns]

# %%
def process_aggregated_user_state(data_directory, engine):
    quarter_data = []

    for state in os.listdir(data_directory):
        state_dir = os.path.join(data_directory, state)
        
        for current_dir, subdirs, files in os.walk(state_dir):
            for file in files:
                file_path = os.path.join(current_dir, file)
                if os.path.isfile(file_path) and file.endswith('.json'):
                    parsed_data = get_data_from_file(file_path)

                    # Extract the necessary information
                    registered_users = parsed_data["data"]["aggregated"]["registeredUsers"]
                    total_open_apps = parsed_data["data"]["aggregated"]["appOpens"]
                    users_by_device = parsed_data["data"]["usersByDevice"]

                    # Check if users_by_device is not None before iterating
                    if users_by_device is not None:
                        # Save the extracted information
                        for user_device in users_by_device:
                            row = {
                                'state': state.lower().replace("&", "-and").replace(" ", "-"),
                                'year': int(os.path.basename(os.path.dirname(file_path))),
                                'quarter': int(file.split('.')[0]),
                                "registered_users": registered_users,
                                "total_open_apps": total_open_apps,
                                "phone_brand": user_device["brand"],
                                "phone_count": user_device["count"],
                                "Percentage": f"{user_device['percentage'] * 100:.2f}",
                            }
                            quarter_data.append(row)

    # Concatenate all DataFrames
    df = pd.DataFrame(quarter_data)

    # Save the DataFrame to the SQLite database table named 'aggregated_user_state'
    df.to_sql('aggregated_user_state', engine, index=False, if_exists='replace')

    # Query the SQLite database to verify the data
    query = 'SELECT * FROM aggregated_user_state;'
    result_df = pd.read_sql(query, engine)
    return result_df

# Example usage:
data_directory_user_state = '/home/user/pulse/data/aggregated/user/country/india/state'
result_df_user_state = process_aggregated_user_state(data_directory_user_state, engine)
result_df_user_state
# Out:
#                  state  year  quarter  registered_users  total_open_apps  \
# 0           chandigarh  2019        2            240439          1220176
# 1           chandigarh  2019        2            240439          1220176
# 2           chandigarh  2019        2            240439          1220176
# 3           chandigarh  2019        2            240439          1220176
# 4           chandigarh  2019        2            240439          1220176
# ...                ...   ...      ...               ...              ...
# 6727  himachal-pradesh  2020        4           1508766         22001148
# 6728  himachal-pradesh  2020        4           1508766         22001148
# 6729  himachal-pradesh  2020        4           1508766         22001148
# 6730  himachal-pradesh  2020        4           1508766         22001148
# 6731  himachal-pradesh  2020        4           1508766         22001148
#
#      phone_brand  phone_count Percentage
# 0         Xiaomi        58356      24.27
# 1        Samsung        48067      19.99
# 2           Vivo        34791      14.47
# 3           Oppo        27444      11.41
# 4          Apple        20041       8.34
# ...          ...          ...        ...
# 6727    Motorola        29156       1.93
# 6728        Lava        29138       1.93
# 6729      Gionee        23461       1.55
# 6730    Micromax        23015       1.53
# 6731      Others       197330      13.08
#
# [6732 rows x 8 columns]

# %%
def process_map_insurance_hover_country(data_directory, engine):
    quarter_data = []

    for current_dir, subdirs, files in os.walk(data_directory):
        for file in files:
            file_path = os.path.join(current_dir, file)
            if os.path.isfile(file_path) and file.endswith('.json'):
                parsed_data = get_data_from_file(file_path)

                table = []
                # Extract the necessary information
                hover_data_list = parsed_data["data"]["hoverDataList"]

                # Save the extracted information
                for entry in hover_data_list:
                    metric_data = entry["metric"][0]  # Extracting the first element of the metric array
                    row = {
                        'year': int(os.path.basename(os.path.dirname(file_path))),
                        'quarter': int(file.split('.')[0]),
                        'state_name': entry["name"],
                        'total_transactions_count': metric_data["count"],
                        'total_transactions_amount': metric_data["amount"],
                    }
                    table.append(row)

                df = pd.DataFrame(table)
                quarter_data.append(df)

    # Concatenate all DataFrames
    df = pd.concat(quarter_data)

    # Save the DataFrame to the SQLite database table named 'map_insurance_hover_country'
    df.to_sql('map_insurance_hover_country', engine, index=False, if_exists='replace')

    # Query the SQLite database to verify the data
    query = 'SELECT * FROM map_insurance_hover_country;'
    result_df = pd.read_sql(query, engine)
    return result_df

# Example usage:
data_map_insurance_hover_country = '/home/user/pulse/data/map/insurance/hover/country/india'
process_map_insurance_hover_country(data_map_insurance_hover_country, engine)
# Out:
#        year  quarter         state_name  total_transactions_count  \
# 0      2023        2         puducherry                      1809
# 1      2023        2         tamil nadu                     79698
# 2      2023        2      uttar pradesh                     74194
# 3      2023        2     madhya pradesh                     27027
# 4      2023        2     andhra pradesh                     36376
# ...     ...      ...                ...                       ...
# 10598  2020        4    jammu & kashmir                       647
# 10599  2020        4                goa                       614
# 10600  2020        4  arunachal pradesh                       125
# 10601  2020        4              delhi                      9725
# 10602  2020        4        uttarakhand                      1756
#
#        total_transactions_amount
# 0                      2614006.0
# 1                    105328191.0
# 2                    122522457.0
# 3                     44871764.0
# 4                     52067478.0
# ...                          ...
# 10598                   734861.0
# 10599                   682364.0
# 10600                    84247.0
# 10601                  8045442.0
# 10602                  1961891.0
#
# [10603 rows x 5 columns]

# %%
def process_map_transaction_hover_state(data_directory, engine):
    quarter_data = []

    for state in os.listdir(data_directory):
        state_dir = os.path.join(data_directory, state)
        
        for current_dir, subdirs, files in os.walk(state_dir):
            for file in files:
                file_path = os.path.join(current_dir, file)
                if os.path.isfile(file_path) and file.endswith('.json'):
                    parsed_data = get_data_from_file(file_path)

                    table = []
                    # Extract the necessary information
                    hover_data_list = parsed_data["data"]["hoverDataList"]

                    # Save the extracted information
                    for entry in hover_data_list:
                        district_name = entry["name"]
                        metric_data = entry["metric"][0]
                        total_transactions_count = metric_data["count"]
                        total_transactions_amount = metric_data["amount"]

                        row = {
                            'year': int(os.path.basename(os.path.dirname(file_path))),
                            'quarter': int(file.split('.')[0]),
                            'state_name/ut_name': state,
                            'districts_name': district_name,
                            'total_transactions_count': total_transactions_count,
                            'total_transactions_amount': total_transactions_amount,
                        }
                        table.append(row)

                    df = pd.DataFrame(table)
                    quarter_data.append(df)

    # Concatenate all DataFrames
    df = pd.concat(quarter_data)

    # Save the DataFrame to the SQLite database table named 'map_transaction_hover_state'
    df.to_sql('map_transaction_hover_state', engine, index=False, if_exists='replace')

    # Query the SQLite database to verify the data
    query = 'SELECT * FROM map_transaction_hover_state;'
    result_df = pd.read_sql(query, engine)
    return result_df

# Example usage:
data_map_transaction_hover_state = '/home/user/pulse/data/map/transaction/hover/country/india/state'
process_map_transaction_hover_state(data_map_transaction_hover_state, engine)
# Out:
#        year  quarter state_name/ut_name            districts_name  \
# 0      2019        2         chandigarh       chandigarh district
# 1      2019        1         chandigarh       chandigarh district
# 2      2019        3         chandigarh       chandigarh district
# 3      2019        4         chandigarh       chandigarh district
# 4      2023        2         chandigarh       chandigarh district
# ...     ...      ...                ...                       ...
# 16827  2020        4   himachal-pradesh            kullu district
# 16828  2020        4   himachal-pradesh            mandi district
# 16829  2020        4   himachal-pradesh  lahul and spiti district
# 16830  2020        4   himachal-pradesh           chamba district
# 16831  2020        4   himachal-pradesh          kinnaur district
#
#        total_transactions_count  total_transactions_amount
# 0                       1252470               2.693116e+09
# 1                       1274476               2.396032e+09
# 2                       1506543               3.269682e+09
# 3                       1850915               4.152514e+09
# 4                      11553687               1.441441e+10
# ...                         ...                        ...
# 16827                    468786               9.640804e+08
# 16828                    671714               1.247938e+09
# 16829                     29377               5.244902e+07
# 16830                    304032               5.078800e+08
# 16831                    104634               2.321314e+08
#
# [16832 rows x 6 columns]

# %%
def process_map_user_hover_country(data_directory, engine):
    quarter_data = []

    for current_dir, subdirs, files in os.walk(data_directory):
        for file in files:
            file_path = os.path.join(current_dir, file)
            if os.path.isfile(file_path) and file.endswith('.json'):
                parsed_data = get_data_from_file(file_path)


                table = []
                # Extract the necessary information
                hover_data = parsed_data["data"]["hoverData"]

                # Extracted information for each state/UT
                for state, state_data in hover_data.items():
                    row = {
                        'year': int(os.path.basename(os.path.dirname(file_path))),
                        'quarter': int(file.split('.')[0]),
                        'state/ut_name': state,
                        'registered_users': state_data["registeredUsers"],
                    }
                    table.append(row)

                df = pd.DataFrame(table)
                quarter_data.append(df)

    # Concatenate all DataFrames
    df = pd.concat(quarter_data)

    # Save the DataFrame to the SQLite database table named 'map_user_hover_country'
    df.to_sql('map_user_hover_country', engine, index=False, if_exists='replace')

    # Query the SQLite database to verify the data
    query = 'SELECT * FROM map_user_hover_country;'
    result_df = pd.read_sql(query, engine)
    return result_df

# Example usage:
data_directory_user_hover_country = '/home/user/pulse/data/map/user/hover/country/india'
process_map_user_hover_country(data_directory_user_hover_country, engine)
# Out:
#        year  quarter      state/ut_name  registered_users
# 0      2019        2         puducherry            156458
# 1      2019        2         tamil nadu           7429609
# 2      2019        2      uttar pradesh          14316349
# 3      2019        2     madhya pradesh           7301172
# 4      2019        2     andhra pradesh           9389003
# ...     ...      ...                ...               ...
# 17659  2020        4    jammu & kashmir           1079022
# 17660  2020        4                goa            527584
# 17661  2020        4  arunachal pradesh            231292
# 17662  2020        4              delhi           9747968
# 17663  2020        4        uttarakhand           2596244
#
# [17664 rows x 4 columns]

# %%
def process_top_insurance_country(data_directory):
    quarter_data = []

    for root, dirs, files in os.walk(data_directory):
        for file in files:
            if file.endswith('.json'):
                file_path = os.path.join(root, file)
                print(f"Processing file: {file_path}")
                parsed_data = get_data_from_file(file_path)

                for entity_type in ['states', 'districts', 'pincodes']:
                    entity_data = [] 
                    entities = parsed_data.get('data', {}).get(entity_type, [])  # Use get() to handle missing keys

                    for entity in entities:
                        entity_row = {
                            'year': int(os.path.basename(os.path.dirname(file_path))),
                            'quarter': int(file.split('.')[0]),
                            'entity_type': entity_type,
                            'entity_name': entity.get('entityName', ''),
                            'transaction_type': entity.get('metric', {}).get('type', ''),
                            'count': entity.get('metric', {}).get('count', 0),
                            'amount': entity.get('metric', {}).get('amount', 0),
                        }

                        entity_data.append(pd.DataFrame([entity_row]))

                    quarter_data.extend(entity_data)

    df = pd.concat(quarter_data, ignore_index=True)
    # df.to_csv('top_insurence_country.csv', index=False)
    # Save the DataFrame to the SQLite database table named 'map_user_hover_country'
    df.to_sql('top_insurence_country', engine, index=False, if_exists='replace')

    # Query the SQLite database to verify the data
    query = 'SELECT * FROM top_insurence_country;'
    result_df = pd.read_sql(query, engine)
    return result_df

    return df

# Example usage:
data_directory = '/home/user/pulse/data/top/insurance/country/india'
result_df = process_top_insurance_country(data_directory)
print(result_df)
# Out:
# Processing file: /home/user/pulse/data/top/insurance/country/india/2023/2.json
# Processing file: /home/user/pulse/data/top/insurance/country/india/2023/1.json
# Processing file: /home/user/pulse/data/top/insurance/country/india/2023/3.json
# Processing file: /home/user/pulse/data/top/insurance/country/india/state/chandigarh/2023/2.json
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/user/pulse/phonepe_data_store_into_sql.ipynb Cell 13 line 4
#      <a href='vscode-notebook-cell://monospace-pulse-1703910431089.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/phonepe_data_store_into_sql.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=41'>42</a> # Example usage:
#      <a href='vscode-notebook-cell://monospace-pulse-1703910431089.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/phonepe_data_store_into_sql.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=42'>43</a> data_directory = '/home/user/pulse/data/top/insurance/country/india'
# ---> <a href='vscode-notebook-cell://monospace-pulse-1703910431089.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/phonepe_data_store_into_sql.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=43'>44</a> result_df = process_top_insurance_country(data_directory)
#      <a href='vscode-notebook-cell://monospace-pulse-1703910431089.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/phonepe_data_store_into_sql.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=44'>45</a> print(result_df)
#
# /home/user/pulse/phonepe_data_store_into_sql.ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell://monospace-pulse-1703910431089.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/phonepe_data_store_into_sql.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> entity_data = []
#      <a href='vscode-notebook-cell://monospace-pulse-1703910431089.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/phonepe_data_store_into_sql.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> entities = parsed_data.get('data', {}).get(entity_type, [])  # Use get() to handle missing keys
# ---> <a href='vscode-notebook-cell://monospace-pulse-1703910431089.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/phonepe_data_store_into_sql.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> for entity in entities:
#      <a href='vscode-notebook-cell://monospace-pulse-1703910431089.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/phonepe_data_store_into_sql.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>     entity_row = {
#      <a href='vscode-notebook-cell://monospace-pulse-1703910431089.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/phonepe_data_store_into_sql.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a>         'year': int(os.path.basename(os.path.dirname(file_path))),
#      <a href='vscode-notebook-cell://monospace-pulse-1703910431089.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/phonepe_data_store_into_sql.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>         'quarter': int(file.split('.')[0]),
#    (...)
#      <a href='vscode-notebook-cell://monospace-pulse-1703910431089.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/phonepe_data_store_into_sql.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a>         'amount': entity.get('metric', {}).get('amount', 0),
#      <a href='vscode-notebook-cell://monospace-pulse-1703910431089.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/phonepe_data_store_into_sql.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>     }
#      <a href='vscode-notebook-cell://monospace-pulse-1703910431089.cluster-22qpi2wzsjc4utjzyqn2yu6ar6.cloudworkstations.dev/home/user/pulse/phonepe_data_store_into_sql.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a>     entity_data.append(pd.DataFrame([entity_row]))
#
# TypeError: 'NoneType' object is not iterable

# %%
import os
import json
import pandas as pd
from sqlalchemy import create_engine

def get_data_from_file(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

def process_top_insurance_state(data_directory, engine):
    quarter_data = []

    for state in os.listdir(data_directory):
        state_dir = os.path.join(data_directory, state)
        for year in range(2018, 2023):
            for quarter in range(1, 5):
                file_path = os.path.join(state_dir, f'{year}/{quarter}.json')
                if os.path.exists(file_path):
                    parsed_data = get_data_from_file(file_path)

                    for entity_type in ['states', 'districts', 'pincodes']:
                        entities = parsed_data['data'].get(entity_type)

                        if entities is not None:
                            entity_data = []

                            for entity in entities:
                                entity_name = entity["entityName"]
                                entity_metric = entity["metric"]

                                row = {
                                    'year': year,
                                    'quarter': quarter,
                                    'entity_type': entity_type,
                                    'entity_name': entity_name,
                                    'transaction_type': entity_metric['type'],
                                    'count': entity_metric['count'],
                                    'amount': entity_metric['amount'],
                                }
                                entity_data.append(row)

                            entity_df = pd.DataFrame(entity_data)
                            quarter_data.append(entity_df)

    df = pd.concat(quarter_data)
    df.to_sql('top_insurance_state', engine, index=False, if_exists='replace')

    # Query the SQLite database to verify the data
    query = 'SELECT * FROM top_insurance_state;'
    result_df = pd.read_sql(query, engine)
    return result_df

# Example usage:
data_directory = '/home/user/pulse/data/top/insurance/country/india/state'

result_df = process_top_insurance_state(data_directory, engine)
print(result_df)
# Out:
#       year  quarter entity_type entity_name transaction_type  count    amount
# 0     2020        2   districts  chandigarh            TOTAL    149   29537.0
# 1     2020        2    pincodes      160101            TOTAL     31    6158.0
# 2     2020        2    pincodes      160047            TOTAL     25    4718.0
# 3     2020        2    pincodes      160036            TOTAL     16    3261.0
# 4     2020        2    pincodes      160023            TOTAL     12    2002.0
# ...    ...      ...         ...         ...              ...    ...       ...
# 7065  2022        4    pincodes      173220            TOTAL     67  128773.0
# 7066  2022        4    pincodes      173212            TOTAL     67  117038.0
# 7067  2022        4    pincodes      176001            TOTAL     65  113046.0
# 7068  2022        4    pincodes      176061            TOTAL     65  146613.0
# 7069  2022        4    pincodes      173001            TOTAL     61  101537.0
#
# [7070 rows x 7 columns]

# %%
import os
import json
import pandas as pd
from sqlalchemy import create_engine

def get_data_from_file(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

def process_top_transaction_country(data_directory, engine):
    quarter_data = []

    for year in range(2018, 2023):
        for quarter in range(1, 5):
            file_path = os.path.join(data_directory, f'{year}/{quarter}.json')
            if os.path.exists(file_path):
                parsed_data = get_data_from_file(file_path)

                for entity_type in ['states', 'districts', 'pincodes']:
                    entity_data = []  

                    entities = parsed_data['data'][entity_type]

                    for entity in entities:
                        entity_row = {
                            'year': year,
                            'quarter': quarter,
                            'entity_type': entity_type,
                            'entity_name': entity['entityName'],
                            'transaction_type': entity['metric']['type'],  
                            'count': entity['metric']['count'],
                            'amount': entity['metric']['amount'],
                        }
                    
                        entity_data.append(entity_row)

                    entity_df = pd.DataFrame(entity_data) 
                    quarter_data.append(entity_df)  

    df = pd.concat(quarter_data)
    df.to_sql('top_transaction_country', engine, index=False, if_exists='replace')

    # Query the SQLite database to verify the data
    query = 'SELECT * FROM top_transaction_country;'
    result_df = pd.read_sql(query, engine)
    return result_df

# Example usage:
data_directory = '/home/user/pulse/data/top/transaction/country/india'

result_df = process_top_transaction_country(data_directory, engine)
print(result_df)
# Out:
#      year  quarter entity_type     entity_name transaction_type      count  \
# 0    2018        1      states     maharashtra            TOTAL   16387034
# 1    2018        1      states   uttar pradesh            TOTAL   12537805
# 2    2018        1      states       karnataka            TOTAL   12016899
# 3    2018        1      states     west bengal            TOTAL   11710225
# 4    2018        1      states  andhra pradesh            TOTAL    9039585
# ..    ...      ...         ...             ...              ...        ...
# 595  2022        4    pincodes          480001            TOTAL  240053791
# 596  2022        4    pincodes          400070            TOTAL  180508440
# 597  2022        4    pincodes          800001            TOTAL  167166031
# 598  2022        4    pincodes          751001            TOTAL  140210762
# 599  2022        4    pincodes          700039            TOTAL  119193886
#
#            amount
# 0    2.171161e+10
# 1    1.393997e+10
# 2    1.921790e+10
# 3    1.062598e+10
# 4    1.199628e+10
# ..            ...
# 595  3.418610e+11
# 596  2.263202e+11
# 597  2.696525e+11
# 598  1.846507e+11
# 599  2.198341e+11
#
# [600 rows x 7 columns]

# %%
import os
import json
import pandas as pd
from sqlalchemy import create_engine

def get_data_from_file(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

def process_top_transaction_state(data_directory, engine):
    quarter_data = []

    for state in os.listdir(data_directory):
        state_dir = os.path.join(data_directory, state)
        for year in range(2018, 2023):
            for quarter in range(1, 5):
                file_path = os.path.join(state_dir, f'{year}/{quarter}.json')
                if os.path.exists(file_path):
                    parsed_data = get_data_from_file(file_path)

                    for entity_type in ['states', 'districts', 'pincodes']:
                        entities = parsed_data['data'].get(entity_type)

                        if entities is not None:
                            entity_data = []  

                            for entity in entities:
                                entity_name = entity["entityName"]
                                entity_metric = entity["metric"]

                                row = {
                                    'year': year,
                                    'quarter': quarter,
                                    'entity_type': entity_type,
                                    'entity_name': entity_name,
                                    'transaction_type': entity_metric['type'],
                                    'count': entity_metric['count'],
                                    'amount': entity_metric['amount'],
                                }
                                entity_data.append(row)

                            entity_df = pd.DataFrame(entity_data)
                            quarter_data.append(entity_df)

    df = pd.concat(quarter_data)
    df.to_sql('top_transaction_state', engine, index=False, if_exists='replace')

    # Query the SQLite database to verify the data
    query = 'SELECT * FROM top_transaction_state;'
    result_df = pd.read_sql(query, engine)
    return result_df

# Example usage:
data_directory = '/home/user/pulse/data/top/transaction/country/india/state'
result_df = process_top_transaction_state(data_directory, engine)
print(result_df)
# Out:
#        year  quarter entity_type entity_name transaction_type   count  \
# 0      2018        1   districts  chandigarh            TOTAL  381895
# 1      2018        1    pincodes      160008            TOTAL  204745
# 2      2018        1    pincodes      160101            TOTAL   26317
# 3      2018        1    pincodes      160002            TOTAL   23236
# 4      2018        1    pincodes      160036            TOTAL   18446
# ...     ...      ...         ...         ...              ...     ...
# 13054  2022        4    pincodes      175001            TOTAL  609639
# 13055  2022        4    pincodes      173025            TOTAL  609183
# 13056  2022        4    pincodes      175101            TOTAL  557239
# 13057  2022        4    pincodes      173212            TOTAL  425394
# 13058  2022        4    pincodes      177001            TOTAL  406943
#
#              amount
# 0      6.134354e+08
# 1      3.034820e+08
# 2      4.562948e+07
# 3      3.400308e+07
# 4      3.089135e+07
# ...             ...
# 13054  8.565356e+08
# 13055  8.116311e+08
# 13056  7.679894e+08
# 13057  5.824669e+08
# 13058  5.930401e+08
#
# [13059 rows x 7 columns]

# %%
import os
import json
import pandas as pd
from sqlalchemy import create_engine

def get_data_from_file(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

def process_top_user_country(data_directory, engine):
    quarter_data = []

    for year in range(2018, 2023):
        for quarter in range(1, 5):
            file_path = os.path.join(data_directory, f'{year}/{quarter}.json')
            if os.path.exists(file_path):
                parsed_data = get_data_from_file(file_path)

                for entity_type in ['states', 'districts', 'pincodes']:
                    entities = parsed_data['data'][entity_type]

                    entity_data = []  

                    for entity in entities:
                        entity_row = {
                            'year': year,
                            'quarter': quarter,
                            'entity_type': entity_type,
                            'entity_name': entity['name'],
                            'registeredUsers': entity['registeredUsers'],
                        }
                        entity_data.append(entity_row)

                    entity_df = pd.DataFrame(entity_data)
                    quarter_data.append(entity_df)

    df = pd.concat(quarter_data)
    df.to_sql('top_user_country', engine, index=False, if_exists='replace')

    # Query the SQLite database to verify the data
    query = 'SELECT * FROM top_user_country;'
    result_df = pd.read_sql(query, engine)
    return result_df

# Example usage:
data_directory = '/home/user/pulse/data/top/user/country/india'

result_df = process_top_user_country(data_directory, engine)
print(result_df)
# Out:
#      year  quarter entity_type     entity_name  registeredUsers
# 0    2018        1      states     maharashtra          6106994
# 1    2018        1      states   uttar pradesh          4694250
# 2    2018        1      states       karnataka          3717763
# 3    2018        1      states  andhra pradesh          3336450
# 4    2018        1      states       telangana          3315560
# ..    ...      ...         ...             ...              ...
# 595  2022        4    pincodes          122001           542209
# 596  2022        4    pincodes          110092           534009
# 597  2022        4    pincodes          110086           477514
# 598  2022        4    pincodes          121004           468607
# 599  2022        4    pincodes          201009           451153
#
# [600 rows x 5 columns]

# %%
import os
import json
import pandas as pd
from sqlalchemy import create_engine
 
# Function to get data from file
def get_data_from_file(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

# Function to process aggregated user country data
def process_aggregated_user_country(data_directory, engine):
    quarter_data = []

    for root, dirs, files in os.walk(data_directory):
        for file in files:
            if file.endswith('.json'):
                file_path = os.path.join(root, file)
                print(f"Processing file: {file_path}")
                parsed_data = get_data_from_file(file_path)

                # Check if 'aggregated' key exists in parsed_data['data']
                if 'data' in parsed_data and 'aggregated' in parsed_data['data']:
                    aggregated_data = parsed_data['data']['aggregated']
                    registered_users = aggregated_data.get('registeredUsers')
                    total_open_apps = aggregated_data.get('appOpens')
                    users_by_device = aggregated_data.get('usersByDevice')
 
                    if users_by_device is not None:
                        table = []
                        # Save the extracted information
                        for user_device in users_by_device:
                            row = {
                                'year': int(os.path.basename(os.path.dirname(file_path))),
                                'quarter': int(file.split('.')[0]),
                                'registered_users': registered_users,
                                'total_open_apps': total_open_apps,
                                'phone_brand': user_device['brand'],
                                'phone_count': user_device['count'],
                                'Percentage': f"{user_device['percentage'] * 100:.2f}",
                            }
                            table.append(row)
 
                        df = pd.DataFrame(table)
                        quarter_data.append(df)

    # Concatenate all DataFrames
    result_df = pd.concat(quarter_data, ignore_index=True)

    # Save the DataFrame to the SQLite database
    result_df.to_sql('aggregated_user_country', engine, index=False, if_exists='replace')

    # Query the SQLite database to verify the data
    query = 'SELECT * FROM aggregated_user_country;'
    result_df = pd.read_sql(query, engine)
    return result_df


data_directory = '/home/user/pulse/data/aggregated/user/country/india/'
# Replace 'sqlite:///your_database_name.db' with the actual path and name of your SQLite database
engine = create_engine('sqlite:///phonepe.sqlite')
result_df = process_aggregated_user_country(data_directory, engine)
print(result_df)
